# %%
import os
from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv())
src_path = os.environ.get('PROJECT_SRC')
os.chdir(src_path)

# %%
from data_reader_writer import data_writer

import pypsa

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams.update({'font.size': 22})

# %% [markdown]
# ## Import and export analysis

# %%
base_case = {'Import': 60.490015, 'Export': 537.888401}
wind_farm = {'Import': 90.941859, 'Export': 484.980111}
low_res = {'Import': 457.870649, 'Export': 52.085804}
battery = {'Import': 60.581919, 'Export': 534.316735}
interconnector = {'Import': 51.351995, 'Export': 546.596946}

df = pd.DataFrame([base_case, wind_farm, low_res, battery, interconnector], 
                  index=['Base case', 'Offshore wind farm failure', 'Low RES output',
                         'Battery failure',
                         'Interconnector issues'])
df

# df_import_export = pd.concat([B6_import, B6_export * -1], axis=1) / 1000000
# df_import_export.columns = ['B6 Import', 'B6 Export']

# df_import_export = df_import_export.groupby(df_import_export.index.to_period('M')).sum()
# df_import_export.index = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df.plot(kind="bar", rot=90, figsize=(11.69, 8.27))
plt.ylabel('GWh')
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
