# %% [markdown]
# # Comparison To Historical Data

# %% [markdown]
# This notebook simulates 2018 using the network constrained LOPF functionality and compares the generation output to historical data published by BEIS.

# %%
import os
from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv())
src_path = os.environ.get('PROJECT_SRC')
os.chdir(src_path)

# %%
import pypsa
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})
plt.style.use('ggplot')
import numpy as np
import pandas as pd
import cartopy.crs as ccrs

import data_reader_writer

# %% [markdown]
# ## Setting up simulation

# %% [markdown]
# Set the required inputs for the LOPF: the start, end and year of simulation, and the timestep.

# %%
# write csv files for import
start = '2018-01-01 00:00:00'
end = '2018-12-31 23:00:00'
# year of simulation
year = 2018
# time step as fraction of hour
time_step = 1

# %% [markdown]
# data_reader_writer is a script written to read in data from the various sources and write csv files in the format required for populating a PyPSA network object

# %%
data_reader_writer.data_writer(start, end, time_step, year, merge_generators=True)
# Out:
# c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\core\indexing.py:1667: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = value

# %%
network = pypsa.Network()

network.import_from_csv_folder('LOPF_data')
# Out:
# WARNING:pypsa.io:
# Importing PyPSA from older version of PyPSA than current version.
# Please read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html
# carefully to prepare your network for import.
# Currently used PyPSA version [0, 19, 2], imported network file PyPSA version None.
#
# INFO:pypsa.components:Applying weightings to all columns of `snapshot_weightings`
# INFO:pypsa.io:Imported network LOPF_data has buses, generators, lines, loads, storage_units

# %% [markdown]
# To approximate n-1 security and allow room for reactive power flows, don't allow any line to be loaded above 70% of their thermal rating

# %%
contingency_factor = 0.7
network.lines.s_max_pu[0:99] *= contingency_factor

# %% [markdown]
# LOPF does not account for losses through lines. Here we add a 10% margin to the load in order to account for these losses.

# %%
network.loads_t.p_set.iloc[:, 0:29] *= 1.1

# %% [markdown]
# ## Running the optimisation

# %%
network.lopf(network.snapshots, solver_name="gurobi", pyomo=False)
# Out:
# INFO:pypsa.linopf:Prepare linear problem
# INFO:pypsa.linopf:Total preparation time: 107.75s
# INFO:pypsa.linopf:Solve linear problem using Gurobi solver
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-09-03
# Read LP format model from file C:\Users\alyden\AppData\Local\Temp\pypsa-problem-yl9h57x6.lp
# Reading time = 63.30 seconds
# obj: 27855382 rows, 7235761 columns, 49237120 nonzeros
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 27855382 rows, 7235761 columns and 49237120 nonzeros
# Model fingerprint: 0x82f6c777
# Coefficient statistics:
#   Matrix range     [6e-05, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-06, 1e+04]
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Presolve removed 0 rows and 0 columns (presolve time = 23s) ...
# Presolve removed 26795438 rows and 43801 columns (presolve time = 27s) ...
# Presolve removed 26795438 rows and 231476 columns (presolve time = 33s) ...
# Presolve removed 26795438 rows and 231476 columns (presolve time = 35s) ...
# Presolve removed 26795438 rows and 5372573 columns (presolve time = 40s) ...
# Presolve removed 26795438 rows and 5372573 columns (presolve time = 50s) ...
# Presolve removed 27222865 rows and 5800000 columns (presolve time = 55s) ...
# Presolve removed 27312209 rows and 5889344 columns (presolve time = 68s) ...
# Presolve removed 27312209 rows and 5889738 columns (presolve time = 70s) ...
# Presolve removed 27312209 rows and 5907393 columns (presolve time = 75s) ...
# Presolve removed 27382281 rows and 5907393 columns
# Presolve time: 80.07s
# Presolved: 473101 rows, 1398440 columns, 2813286 nonzeros
#
# Ordering time: 0.50s
#
# Barrier statistics:
#  AA' NZ     : 1.776e+06
#  Factor NZ  : 1.015e+07 (roughly 800 MB of memory)
#  Factor Ops : 3.278e+08 (less than 1 second per iteration)
#  Threads    : 3
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2
#   29   8.61355474e+09  8.61351671e+09  4.81e-05 6.79e-14  1.36e-02   108s
#   30   8.61354856e+09  8.61352308e+09  3.04e-05 6.21e-14  9.08e-03   108s
#   31   8.61354800e+09  8.61352473e+09  2.87e-05 7.43e-14  8.30e-03   109s
#   32   8.61354285e+09  8.61353348e+09  1.37e-05 9.07e-14  3.34e-03   110s
#   33   8.61353892e+09  8.61353717e+09  2.34e-06 9.32e-14  6.22e-04   111s
#   34   8.61353806e+09  8.61353774e+09  2.49e-06 1.59e-11  1.14e-04   113s
#   35   8.61353795e+09  8.61353791e+09  1.09e-06 1.56e-11  1.17e-05   114s
#   36   8.61353794e+09  8.61353794e+09  5.34e-08 4.34e-12  1.10e-07   115s
#   37   8.61353794e+09  8.61353794e+09  2.46e-09 8.26e-14  2.64e-12   116s
#
# Barrier solved model in 37 iterations and 116.25 seconds (45.13 work units)
# Optimal objective 8.61353794e+09
#
# Crossover log...
#
#    60347 DPushes remaining with DInf 0.0000000e+00               120s
#        0 DPushes remaining with DInf 0.0000000e+00               123s
#
#   158274 PPushes remaining with PInf 0.0000000e+00               123s
#    69237 PPushes remaining with PInf 0.0000000e+00               125s
#    32624 PPushes remaining with PInf 0.0000000e+00               133s
#    25580 PPushes remaining with PInf 0.0000000e+00               137s
#    18881 PPushes remaining with PInf 0.0000000e+00               140s
#     7636 PPushes remaining with PInf 0.0000000e+00               147s
#     4319 PPushes remaining with PInf 0.0000000e+00               151s
#     2355 PPushes remaining with PInf 0.0000000e+00               158s
#        0 PPushes remaining with PInf 0.0000000e+00               160s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.4686752e-09    160s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   183590    8.6135379e+09   0.000000e+00   0.000000e+00    205s
#
# Solved with barrier
# Solved in 183590 iterations and 204.76 seconds (87.86 work units)
# Optimal objective  8.613537940e+09
# INFO:pypsa.linopf:Optimization successful. Objective value: 8.61e+09
# ('ok', 'optimal')

# %% [markdown]
# ## Power output by generation type

# %% [markdown]
# Group the generators by the carrier, and print their summed power outputs over the simulation period.

# %%
p_by_carrier = network.generators_t.p.groupby(
    network.generators.carrier, axis=1).sum()

storage_by_carrier = network.storage_units_t.p.groupby(
    network.storage_units.carrier, axis=1).sum()

# to show on graph set the negative storage values to zero
storage_by_carrier[storage_by_carrier < 0] = 0

p_by_carrier = pd.concat([p_by_carrier, storage_by_carrier], axis=1)

# interconnector exports
exports = network.loads_t.p
# multiply by negative one to convert it as a generator
# i.e. export is a positive load, but negative generator
exports['Interconnectors Export'] = exports.iloc[:, -6:].sum(axis=1) * -1
interconnector_export = exports[['Interconnectors Export']]

# group biomass stuff
p_by_carrier['Biomass'] = (
    p_by_carrier['Biomass (dedicated)'] + p_by_carrier['Biomass (co-firing)'] +
    p_by_carrier['Landfill Gas'] + p_by_carrier['Anaerobic Digestion'] +
    p_by_carrier['Sewage Sludge Digestion'])

# rename the hydro bit
p_by_carrier = p_by_carrier.rename(
    columns={'Large Hydro': 'Hydro'})
p_by_carrier = p_by_carrier.rename(
    columns={'Interconnector': 'Interconnectors Import'})

# %store p_by_carrier
p_by_carrier
# Out:
# 2018-01-01 00:00:00            24.0    40.564332                  0.0
# 2018-01-01 01:00:00            24.0    39.989766                  0.0
# 2018-01-01 02:00:00            24.0    38.093700                  0.0
# 2018-01-01 03:00:00            24.0    32.175674                  0.0
# 2018-01-01 04:00:00            24.0    31.256368                  0.0
# ...                             ...          ...                  ...
# 2018-12-31 19:00:00            23.0    30.493284                  0.0
# 2018-12-31 20:00:00            23.0    28.508955                  0.0
# 2018-12-31 21:00:00            23.0    28.002879                  0.0
# 2018-12-31 22:00:00            23.0    21.310254                  0.0
# 2018-12-31 23:00:00            23.0    21.945209                  0.0
#
# carrier              Tidal Barrage and Tidal Stream  Wind Offshore  \
# snapshot
# 2018-01-01 00:00:00                             8.0    5322.763752
# 2018-01-01 01:00:00                             8.0    5318.656864
# 2018-01-01 02:00:00                             8.0    5315.245105
# 2018-01-01 03:00:00                             8.0    5312.001825
# 2018-01-01 04:00:00                             8.0    5306.942938
# ...                                             ...            ...
# 2018-12-31 19:00:00                             8.0    4149.432488
# 2018-12-31 20:00:00                             8.0    4517.427141
# 2018-12-31 21:00:00                             8.0    4932.236202
# 2018-12-31 22:00:00                             8.0    5252.235248
# 2018-12-31 23:00:00                             8.0    5246.397310
#
# carrier              Wind Onshore  Pumped Storage Hydroelectric      Biomass
# snapshot
# 2018-01-01 00:00:00   6499.869773                      0.000000  1128.829000
# 2018-01-01 01:00:00   6233.178739                     87.824506  1108.900000
# 2018-01-01 02:00:00   6067.016448                    108.320942  1108.900000
# 2018-01-01 03:00:00   5988.198334                     64.542325  1108.900000
# 2018-01-01 04:00:00   5794.067603                    116.232549  1108.900000
# ...                           ...                           ...          ...
# 2018-12-31 19:00:00   7659.397105                    417.694273  3889.003000
# 2018-12-31 20:00:00   7417.002223                   1459.314444  3889.003000
# 2018-12-31 21:00:00   7502.765267                    347.661362  3889.003000
# 2018-12-31 22:00:00   7119.071077                    600.121632  3854.703000
# 2018-12-31 23:00:00   6884.088345                      0.000000  3865.772831
#
# [8760 rows x 20 columns]

# %% [markdown]
# Graph the power output of the different generation types...

# %%
cols = ["Nuclear", 'Shoreline Wave', 'Biomass',
        'EfW Incineration',
        "Coal", "Oil", "Natural Gas",
        "Pumped Storage Hydroelectric", 'Hydro',
        "Wind Offshore", 'Wind Onshore', 'Solar Photovoltaics',
        'Interconnectors Import'
        ]

p_by_carrier = p_by_carrier[cols]

p_by_carrier.drop(
    (p_by_carrier.max()[p_by_carrier.max() < 50.0]).index,
    axis=1, inplace=True)


colors = {"Coal": "grey",
          "Diesel/Gas oil": "black",
          "Diesel/gas Diesel/Gas oil": "black",
          'Oil': 'black',
          'Anaerobic Digestion': 'green',
          'EfW Incineration': 'chocolate',
          'Sewage Sludge Digestion': 'green',
          'Landfill Gas': 'green',
          'Biomass (dedicated)': 'green',
          'Biomass (co-firing)': 'green',
          'Biomass': 'green',
          'Interconnectors Import': 'pink',
          "Sour gas": "lightcoral",
          "Natural Gas": "lightcoral",
          "Nuclear": "orange",
          'Shoreline Wave': 'aqua',
          'Tidal Barrage and Tidal Stream': 'aqua',
          'Hydro': "turquoise",
          "Large Hydro": "turquoise",
          "Small Hydro": "turquoise",
          "Pumped Storage Hydroelectric": "darkturquoise",
          "Wind Offshore": "lightskyblue",
          'Wind Onshore': 'deepskyblue',
          'Solar Photovoltaics': 'yellow'}

fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15,10)
(p_by_carrier / 1e3).plot(
    kind="area", ax=ax, linewidth=0,
    color=[colors[col] for col in p_by_carrier.columns])

# stacked area plot of negative values, prepend column names with '_' such that they don't appear in the legend
(interconnector_export / 1e3).plot.area(ax=ax, stacked=True, linewidth=0.)
# rescale the y axis
ax.set_ylim([(interconnector_export / 1e3).sum(axis=1).min(), (p_by_carrier / 1e3).sum(axis=1).max()])

# Shrink current axis's height by 10% on the bottom
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])

# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
          fancybox=True, shadow=True, ncol=5)

ax.set_ylabel("GW")

ax.set_xlabel("")
# Out:
# c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\plotting\_matplotlib\core.py:1391: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(None, 0)
# Text(0.5, 0, '')

# %% [markdown]
# ## Simulated vs historical data power generation

# %% [markdown]
# We can group the generators by type and sum to calculate the total simulated power generation over the year in TWh.

# %%
# %store -r p_by_carrier

p_by_carrier = p_by_carrier.sum() / 1000000
# print(p_by_carrier)
p_by_carrier['Hydro'] = p_by_carrier['Small Hydro'] + p_by_carrier['Hydro']
p_by_carrier['Oil'] = 0.
p_by_carrier.drop(['Small Hydro', 'Anaerobic Digestion', 'Biomass (co-firing)', 'Biomass (dedicated)', 'Landfill Gas', 'Sewage Sludge Digestion', 'Shoreline Wave', 'Tidal Barrage and Tidal Stream'], inplace=True)
p_by_carrier
# Out:
# carrier
# Coal                              2.918946
# EfW Incineration                  3.474006
# Interconnectors Import           21.929185
# Hydro                             2.864075
# Natural Gas                     139.811284
# Nuclear                          59.559250
# Oil                               0.000000
# Solar Photovoltaics              14.709815
# Wind Offshore                    26.046430
# Wind Onshore                     28.842322
# Pumped Storage Hydroelectric      0.566589
# Biomass                          31.112507
# dtype: float64

# %% [markdown]
# Then the total of all simulated power generation is:

# %%
p_by_carrier.sum()
# Out:
# 331.83440664374297

# %% [markdown]
# BEIS publish reports on power generation. We extracted the data for 2018 from "Table 5c: electricity supplied by fuel 1998 to 2020 (TWh)" in ET5.1 (power generation) and ET5.6 (imports) https://www.gov.uk/government/statistics/electricity-section-5-energy-trends. Additional data for EfW Incineration was obtained from the DUKES dataset https://www.gov.uk/government/collections/digest-of-uk-energy-statistics-dukes.

# %%
data = {'Coal': 16.0,
        'EfW Incineration': 3.5,
        'Interconnectors Import': 21.9,
        'Hydro': 5.4,
        'Natural Gas': 129.1,
        'Nuclear': 59.1,
        'Oil': 1.0,
        'Solar Photovoltaics': 12.7,
        'Wind Offshore': 26.5,
        'Wind Onshore': 30.4,
        'Pumped Storage Hydroelectric': 0.0,
        'Biomass': 31.5
        }
data_series = pd.Series(data)
data_series
# Out:
# Coal                             16.0
# EfW Incineration                  3.5
# Interconnectors Import           21.9
# Hydro                             5.4
# Natural Gas                     129.1
# Nuclear                          59.1
# Oil                               1.0
# Solar Photovoltaics              12.7
# Wind Offshore                    26.5
# Wind Onshore                     30.4
# Pumped Storage Hydroelectric      0.0
# Biomass                          31.5
# dtype: float64

# %%
data_series.sum()
# Out:
# 337.09999999999997

# %%
data_series.index
# Out:
# Index(['Coal', 'EfW Incineration', 'Interconnectors Import', 'Hydro',
#        'Natural Gas', 'Nuclear', 'Oil', 'Solar Photovoltaics', 'Wind Offshore',
#        'Wind Onshore', 'Pumped Storage Hydroelectric', 'Biomass'],
#       dtype='object')

# %%
# mylabels = data_series.index
# mycolors = categorical_cmap(3, 10)

colors = {"Coal": "grey",
          "Diesel/Gas oil": "black",
          "Diesel/gas Diesel/Gas oil": "black",
          'Oil': 'black',
          'Anaerobic Digestion': 'green',
          'EfW Incineration': 'chocolate',
          'Sewage Sludge Digestion': 'green',
          'Landfill Gas': 'green',
          'Biomass (dedicated)': 'green',
          'Biomass (co-firing)': 'green',
          'Biomass': 'green',
          'Interconnectors Import': 'pink',
          "Sour gas": "lightcoral",
          "Natural Gas": "lightcoral",
          "Nuclear": "orange",
          'Shoreline Wave': 'aqua',
          'Tidal Barrage and Tidal Stream': 'aqua',
          'Hydro': "turquoise",
          "Large Hydro": "turquoise",
          "Small Hydro": "turquoise",
          "Pumped Storage Hydroelectric": "darkturquoise",
          "Wind Offshore": "lightskyblue",
          'Wind Onshore': 'deepskyblue',
          'Solar Photovoltaics': 'yellow'}

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(20,15)

ax1.pie(data_series, labels=data_series.index,
        colors=[colors[col] for col in p_by_carrier.index], autopct="%1.1f%%",
        startangle=90, pctdistance=1.1, labeldistance=1.2)
ax1.set_title('Historical data')

simulated_generation = p_by_carrier
ax2.pie(simulated_generation, labels=simulated_generation.index,
        colors=[colors[col] for col in p_by_carrier.index], autopct="%1.1f%%",
        startangle=90, pctdistance=1.1, labeldistance=1.2)
ax2.set_title('Simulated data')

plt.tight_layout()

# %%
df = pd.DataFrame([simulated_generation, data_series], index=['Simulated', 'Historical']).T.round(1)
df.fillna(0, inplace=True)
df['Simulated - Historical'] = df['Simulated'] - df['Historical']
df['Simulated (%)'] = (df['Simulated'] / df['Simulated'].sum()* 100).round(1)
df['Historical (%)'] = (df['Historical'] / df['Historical'].sum()* 100).round(1)
df['Simulated (%) - Historical (%)'] = df['Simulated (%)'] - df['Historical (%)']
df.loc["Total"] = df.sum().round(2)
df
# Out:
#                               Simulated  Historical  Simulated - Historical  \
# Coal                                2.9        16.0                   -13.1
# EfW Incineration                    3.5         3.5                     0.0
# Interconnectors Import             21.9        21.9                     0.0
# Hydro                               2.9         5.4                    -2.5
# Natural Gas                       139.8       129.1                    10.7
# Nuclear                            59.6        59.1                     0.5
# Oil                                 0.0         1.0                    -1.0
# Solar Photovoltaics                14.7        12.7                     2.0
# Wind Offshore                      26.0        26.5                    -0.5
# Wind Onshore                       28.8        30.4                    -1.6
# Pumped Storage Hydroelectric        0.6         0.0                     0.6
# Biomass                            31.1        31.5                    -0.4
# Total                             331.8       337.1                    -5.3
#
#                               Simulated (%)  Historical (%)  \
# Coal                                    0.9             4.7
# EfW Incineration                        1.1             1.0
# Interconnectors Import                  6.6             6.5
# Hydro                                   0.9             1.6
# Natural Gas                            42.1            38.3
# Nuclear                                18.0            17.5
# Oil                                     0.0             0.3
# Solar Photovoltaics                     4.4             3.8
# Wind Offshore                           7.8             7.9
# Wind Onshore                            8.7             9.0
# Pumped Storage Hydroelectric            0.2             0.0
# Biomass                                 9.4             9.3
# Total                                 100.1            99.9
#
#                               Simulated (%) - Historical (%)
# Coal                                                    -3.8
# EfW Incineration                                         0.1
# Interconnectors Import                                   0.1
# Hydro                                                   -0.7
# Natural Gas                                              3.8
# Nuclear                                                  0.5
# Oil                                                     -0.3
# Solar Photovoltaics                                      0.6
# Wind Offshore                                           -0.1
# Wind Onshore                                            -0.3
# Pumped Storage Hydroelectric                             0.2
# Biomass                                                  0.1
# Total                                                    0.2

# %% [markdown]
# Looking at table above we can see (i) Gas too high, and (ii) Coal too low.
#
# Likely due to price dynamics of gas and coal which are not fully captured in marginal cost, e.g., capacity markets.

# %%
N = len(data_series.index)
data = data_series.values
sim = p_by_carrier.values

ind = np.arange(N) 
width = 0.35
plt.figure(figsize=(20, 10))
plt.bar(ind, data, width, label='Data from BEIS')
plt.bar(ind + width, sim, width, label='Output from PyPSA-GB')

plt.ylabel('Generation by type in 2018 (TWh)')
# plt.title('Scores by group and gender')

plt.xticks(ind + width / 2, data_series.index)
plt.setp(plt.gca().get_xticklabels(), rotation=90, horizontalalignment='right')
plt.legend(loc='best')
plt.show()
