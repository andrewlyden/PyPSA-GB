# %%
import os
from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv())
src_path = os.environ.get('PROJECT_SRC')
os.chdir(src_path)

# %%
from data_reader_writer import data_writer

import pypsa

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ## System Transformation - 2045

# %%
# scenario = 'Leading The Way'
# scenario = 'Consumer Transformation'
scenario = 'System Transformation'
# scenario = 'Steady Progression'
year = 2045
year_baseline = 2012

start = str(year) + '-12-07 00:00:00'
end = str(year) + '-12-07 23:30:00'
# time step as fraction of hour
time_step = 0.5
data_writer(start, end, time_step, year, demand_dataset='eload', year_baseline=year_baseline,
            scenario=scenario, FES=2022, merge_generators=True, scale_to_peak=True)

df_generators = pd.read_csv('LOPF_data/generators.csv', index_col=0)
buses_scotland = ['Beauly', 'Peterhead', 'Errochty', 'Denny/Bonnybridge', 'Neilston', 'Strathaven', 'Torness', 'Eccles']
# select generators in the buses in Scotland
df_generators_scotland = df_generators[df_generators.bus.isin(buses_scotland)]
generators_p_nom_scotland = df_generators_scotland.p_nom.groupby(
    df_generators_scotland.carrier).sum().sort_values()
if year > 2020:
    generators_p_nom_scotland.drop(['Unmet Load', 'CCS Biomass'], inplace=True)
generators_p_nom_scotland.drop(generators_p_nom_scotland[generators_p_nom_scotland < 50].index, inplace=True)
print(generators_p_nom_scotland)

plt.rcParams.update({'font.size': 22})
# bar chart
plt.figure(figsize=(15,5))
plt.bar(generators_p_nom_scotland.index, generators_p_nom_scotland.values / 1000)
plt.xticks(generators_p_nom_scotland.index, rotation=90)
plt.ylabel('GW')
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
plt.title('Scotland installed generation capacity in year ' + str(year))
plt.show()
# Out:
# c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\core\arrays\datetimes.py:741: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex
#   warnings.warn(
# c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\core\indexing.py:1667: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = value
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB v0.0.1\PyPSA-GB\interconnectors.py:206: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   df_FES = df_FES[~df_FES.Variable.str.contains('(TWh)')]
# carrier
# Biomass (dedicated)       61.446000
# Waste                     62.176000
# Wave power               113.000000
# Small Hydro              230.913108
# Large Hydro             1691.699577
# CCS Gas                 1810.000000
# Hydrogen                1924.474994
# Nuclear                 3168.250000
# Solar Photovoltaics     3947.294084
# Wind Onshore           23890.538179
# Wind Offshore          33901.090000
# Name: p_nom, dtype: float64

# %%
network = pypsa.Network()
network.import_from_csv_folder('LOPF_data')
loads = network.loads_t.p_set
print(loads)
buses_scotland = ['Beauly', 'Peterhead', 'Errochty', 'Denny/Bonnybridge', 'Neilston', 'Strathaven', 'Torness', 'Eccles']
# select generators in the buses in Scotland
# loads_scotland = 
loads[buses_scotland].sum(axis=1).plot()
loads[buses_scotland].sum(axis=1).max()
# loads_scotland
# Out:
# WARNING:pypsa.io:
# Importing PyPSA from older version of PyPSA than current version.
# Please read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html
# carefully to prepare your network for import.
# Currently used PyPSA version [0, 20, 1], imported network file PyPSA version None.
#
# INFO:pypsa.components:Applying weightings to all columns of `snapshot_weightings`
# INFO:pypsa.io:Imported network LOPF_data has buses, generators, lines, links, loads, storage_units
# Load                     Beauly    Peterhead    Errochty  Denny/Bonnybridge  \
# snapshot
# 2045-12-07 00:00:00  499.460407   807.557022  268.321916        2392.015699
# 2045-12-07 00:30:00  482.546942   780.210334  259.235603        2311.013732
# snapshot
# 2045-12-07 00:00:00   5084.810114
# 2045-12-07 00:30:00   4912.620768
# 2045-12-07 01:00:00   4715.041458
# 2045-12-07 01:30:00   4528.065742
# 2045-12-07 02:00:00   4422.800339
# 2045-12-07 02:30:00   4470.351967
# 2045-12-07 03:00:00   4534.854088
# 2045-12-07 03:30:00   4480.440166
# 2045-12-07 04:00:00   4368.179384
# 2045-12-07 04:30:00   4259.140926
# 2045-12-07 05:00:00   4254.391009
# 2045-12-07 05:30:00   4454.995853
# 2045-12-07 06:00:00   4761.187293
# 2045-12-07 06:30:00   5073.197165
# 2045-12-07 07:00:00   5333.273678
# 2045-12-07 07:30:00   5483.665042
# 2045-12-07 08:00:00   5568.295861
# 2045-12-07 08:30:00   5631.090741
# 2045-12-07 09:00:00   5670.377483
# 2045-12-07 09:30:00   5684.483888
# 2045-12-07 10:00:00   5683.842626
# 2045-12-07 10:30:00   5678.886366
# 2045-12-07 11:00:00   5676.112050
# 2045-12-07 11:30:00   5682.016617
# 2045-12-07 12:00:00   5683.383227
# 2045-12-07 12:30:00   5666.995038
# 2045-12-07 13:00:00   5658.742016
# 2045-12-07 13:30:00   5684.514125
# 2045-12-07 14:00:00   5716.048079
# 2045-12-07 14:30:00   5725.080588
# 2045-12-07 15:00:00   5791.064764
# 2045-12-07 15:30:00   5993.453715
# 2045-12-07 16:00:00   6231.335324
# 2045-12-07 16:30:00   6403.797475
# 2045-12-07 17:00:00   6565.690655
# 2045-12-07 17:30:00   6771.865354
# 2045-12-07 18:00:00   7006.729520
# 2045-12-07 18:30:00   7254.691103
# 2045-12-07 19:00:00   7483.379726
# 2045-12-07 19:30:00   7660.425013
# 2045-12-07 20:00:00   7699.384376
# 2045-12-07 20:30:00   7513.815230
# 2045-12-07 21:00:00   7158.948997
# 2045-12-07 21:30:00   6690.017099
# 2045-12-07 22:00:00   6191.510184
# 2045-12-07 22:30:00   5747.918901
# 2045-12-07 23:00:00   5420.068403
# 2045-12-07 23:30:00   5268.783841
#
# [48 rows x 29 columns]
# 13057.97168667325

# %% [markdown]
# ## System Transformation - 2040

# %%
# scenario = 'Leading The Way'
# scenario = 'Consumer Transformation'
scenario = 'System Transformation'
# scenario = 'Steady Progression'
year = 2040
year_baseline = 2012

start = str(year) + '-12-02 00:00:00'
end = str(year) + '-12-02 00:30:00'
# time step as fraction of hour
time_step = 0.5
data_writer(start, end, time_step, year, demand_dataset='eload', year_baseline=year_baseline,
            scenario=scenario, FES=2022, merge_generators=False, scale_to_peak=True)

df_generators = pd.read_csv('LOPF_data/generators.csv', index_col=0)
buses_scotland = ['Beauly', 'Peterhead', 'Errochty', 'Denny/Bonnybridge', 'Neilston', 'Strathaven', 'Torness', 'Eccles']
# select generators in the buses in Scotland
df_generators_scotland = df_generators[df_generators.bus.isin(buses_scotland)]
generators_p_nom_scotland = df_generators_scotland.p_nom.groupby(
    df_generators_scotland.carrier).sum().sort_values()
if year > 2020:
    generators_p_nom_scotland.drop(['Unmet Load', 'CCS Biomass'], inplace=True)
generators_p_nom_scotland.drop(generators_p_nom_scotland[generators_p_nom_scotland < 50].index, inplace=True)
print(generators_p_nom_scotland)

plt.rcParams.update({'font.size': 22})
# bar chart
plt.figure(figsize=(15,5))
plt.bar(generators_p_nom_scotland.index, generators_p_nom_scotland.values / 1000)
plt.xticks(generators_p_nom_scotland.index, rotation=90)
plt.ylabel('GW')
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
plt.title('Scotland installed generation capacity in year ' + str(year))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 12
#      10 # time step as fraction of hour
#      11 time_step = 0.5
# ---> 12 data_writer(start, end, time_step, year, demand_dataset='eload', year_baseline=year_baseline,
#      13             scenario=scenario, FES=2022, merge_generators=False, scale_to_peak=True)
#      15 df_generators = pd.read_csv('LOPF_data/generators.csv', index_col=0)
#      16 buses_scotland = ['Beauly', 'Peterhead', 'Errochty', 'Denny/Bonnybridge', 'Neilston', 'Strathaven', 'Torness', 'Eccles']
#
# File ~\OneDrive - University of Edinburgh\Python\PyPSA-GB v0.0.1\PyPSA-GB\data_reader_writer.py:63, in data_writer(start, end, time_step, year, demand_dataset, year_baseline, scenario, FES, merge_generators, scale_to_peak)
#      61 if year > 2020:
#      62     storage.write_storage_units(year, scenario=scenario, FES=FES)
# ---> 63     generators.future_p_nom(year, time_step, scenario, FES)
#      64     generators.write_generators_p_max_pu(start, end, freq, year, FES, year_baseline=year_baseline, scenario=scenario)
#      65     # renewables.add_marine_timeseries(year, year_baseline, scenario, time_step)
#
# File ~\OneDrive - University of Edinburgh\Python\PyPSA-GB v0.0.1\PyPSA-GB\generators.py:1713, in future_p_nom(year, time_step, scenario, FES)
#    1711 future_oil_p_nom(year, scenario, FES)
#    1712 future_waste_p_nom(year, scenario, FES)
# -> 1713 renewables.future_RES_scale_p_nom(year, 'Wind Onshore', scenario, FES)
#    1714 renewables.future_RES_scale_p_nom(year, 'Solar Photovoltaics', scenario, FES)
#    1715 renewables.future_RES_scale_p_nom(year, 'Hydro', scenario, FES)
#
# File ~\OneDrive - University of Edinburgh\Python\PyPSA-GB v0.0.1\PyPSA-GB\renewables.py:1154, in future_RES_scale_p_nom(year, tech, scenario, FES)
#    1152 def future_RES_scale_p_nom(year, tech, scenario, FES):
# -> 1154     future_capacities_dict = future_RES_capacity(year, tech, scenario, FES)
#    1155     tech_cap_year = future_capacities_dict['tech_cap_year']
#    1156     tech_cap_FES = future_capacities_dict['tech_cap_FES']
#
# File ~\OneDrive - University of Edinburgh\Python\PyPSA-GB v0.0.1\PyPSA-GB\renewables.py:1552, in future_RES_capacity(year, tech, scenario, FES)
#    1550     df_FES.dropna(axis='rows', inplace=True)
#    1551 if FES == 2022:
# -> 1552     df_FES = pd.read_excel(
#    1553         '../data/FES2022/FES2022 Workbook V4.xlsx',
#    1554         sheet_name='ES1', header=9, index_col=1)
#    1555     df_FES = df_FES[df_FES.SubType.str.contains('Onshore Wind', case=False, na=False)]
#    1556     df_FES = df_FES[~df_FES.Variable.str.contains('Generation')]
#
# File c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\io\excel\_base.py:364, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362 if not isinstance(io, ExcelFile):
#     363     should_close = True
# --> 364     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365 elif engine and engine != io.engine:
#     366     raise ValueError(
#     367         "Engine should not be specified when passing "
#     368         "an ExcelFile - ExcelFile already has the engine set"
#     369     )
#
# File c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\io\excel\_base.py:1233, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1230 self.engine = engine
#    1231 self.storage_options = storage_options
# -> 1233 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\io\excel\_openpyxl.py:522, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     511 """
#     512 Reader using openpyxl engine.
#     513
#    (...)
#     519     passed to fsspec for appropriate URLs (see ``_get_filepath_or_buffer``)
#     520 """
#     521 import_optional_dependency("openpyxl")
# --> 522 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\io\excel\_base.py:420, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     418 self.handles.handle.seek(0)
#     419 try:
# --> 420     self.book = self.load_workbook(self.handles.handle)
#     421 except Exception:
#     422     self.close()
#
# File c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\io\excel\_openpyxl.py:533, in OpenpyxlReader.load_workbook(self, filepath_or_buffer)
#     530 def load_workbook(self, filepath_or_buffer: FilePathOrBuffer):
#     531     from openpyxl import load_workbook
# --> 533     return load_workbook(
#     534         filepath_or_buffer, read_only=True, data_only=True, keep_links=False
#     535     )
#
# File c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\openpyxl\reader\excel.py:317, in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     290 """Open the given filename and return the workbook
#     291
#     292 :param filename: the path to open or a file-like object
#    (...)
#     313
#     314 """
#     315 reader = ExcelReader(filename, read_only, keep_vba,
#     316                     data_only, keep_links)
# --> 317 reader.read()
#     318 return reader.wb
#
# File c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\openpyxl\reader\excel.py:282, in ExcelReader.read(self)
#     280 self.read_theme()
#     281 apply_stylesheet(self.archive, self.wb)
# --> 282 self.read_worksheets()
#     283 self.parser.assign_names()
#     284 if not self.read_only:
#
# File c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\openpyxl\reader\excel.py:219, in ExcelReader.read_worksheets(self)
#     216     rels = get_dependents(self.archive, rels_path)
#     218 if self.read_only:
# --> 219     ws = ReadOnlyWorksheet(self.wb, sheet.name, rel.target, self.shared_strings)
#     220     ws.sheet_state = sheet.state
#     221     self.wb._sheets.append(ws)
#
# File c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\openpyxl\worksheet\_read_only.py:41, in ReadOnlyWorksheet.__init__(self, parent_workbook, title, worksheet_path, shared_strings)
#      39 self._worksheet_path = worksheet_path
#      40 self._shared_strings = shared_strings
# ---> 41 self._get_size()
#
# File c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\openpyxl\worksheet\_read_only.py:45, in ReadOnlyWorksheet._get_size(self)
#      44 def _get_size(self):
# ---> 45     src = self._get_source()
#      46     parser = WorkSheetParser(src, [])
#      47     dimensions = parser.parse_dimensions()
#
# File c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\openpyxl\worksheet\_read_only.py:55, in ReadOnlyWorksheet._get_source(self)
#      53 def _get_source(self):
#      54     """Parse xml source on demand, must close after use"""
# ---> 55     return self.parent._archive.open(self._worksheet_path)
#
# File c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\zipfile.py:1530, in ZipFile.open(self, name, mode, pwd, force_zip64)
#    1526 zef_file = _SharedFile(self.fp, zinfo.header_offset,
#    1527                        self._fpclose, self._lock, lambda: self._writing)
#    1528 try:
#    1529     # Skip the file header:
# -> 1530     fheader = zef_file.read(sizeFileHeader)
#    1531     if len(fheader) != sizeFileHeader:
#    1532         raise BadZipFile("Truncated file header")
#
# File c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\zipfile.py:764, in _SharedFile.read(self, n)
#     760     raise ValueError("Can't read from the ZIP file while there "
#     761             "is an open writing handle on it. "
#     762             "Close the writing handle before trying to read.")
#     763 self._file.seek(self._pos)
# --> 764 data = self._file.read(n)
#     765 self._pos = self._file.tell()
#     766 return data
#
# KeyboardInterrupt:

# %% [markdown]
# ## System Transformation - 2035

# %%
# scenario = 'Leading The Way'
# scenario = 'Consumer Transformation'
scenario = 'System Transformation'
# scenario = 'Steady Progression'
year = 2035
year_baseline = 2012

start = str(year) + '-12-02 00:00:00'
end = str(year) + '-12-02 00:30:00'
# time step as fraction of hour
time_step = 0.5
data_writer(start, end, time_step, year, demand_dataset='eload', year_baseline=year_baseline,
            scenario=scenario, FES=2022, merge_generators=False, scale_to_peak=True)

df_generators = pd.read_csv('LOPF_data/generators.csv', index_col=0)
buses_scotland = ['Beauly', 'Peterhead', 'Errochty', 'Denny/Bonnybridge', 'Neilston', 'Strathaven', 'Torness', 'Eccles']
# select generators in the buses in Scotland
df_generators_scotland = df_generators[df_generators.bus.isin(buses_scotland)]
generators_p_nom_scotland = df_generators_scotland.p_nom.groupby(
    df_generators_scotland.carrier).sum().sort_values()
if year > 2020:
    generators_p_nom_scotland.drop(['Unmet Load', 'CCS Biomass', 'Natural Gas'], inplace=True)
generators_p_nom_scotland.drop(generators_p_nom_scotland[generators_p_nom_scotland < 50].index, inplace=True)
print(generators_p_nom_scotland)

plt.rcParams.update({'font.size': 22})
# bar chart
plt.figure(figsize=(15,5))
plt.bar(generators_p_nom_scotland.index, generators_p_nom_scotland.values / 1000)
plt.xticks(generators_p_nom_scotland.index, rotation=90)
plt.ylabel('GW')
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
plt.title('Scotland installed generation capacity in year ' + str(year))
plt.show()
# Out:
# c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\core\arrays\datetimes.py:741: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex
#   warnings.warn(
# c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\core\indexing.py:1667: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = value
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB v0.0.1\PyPSA-GB\interconnectors.py:206: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   df_FES = df_FES[~df_FES.Variable.str.contains('(TWh)')]
# carrier
# Biomass (dedicated)       74.480000
# Waste                     75.168000
# Wave power                88.000000
# Small Hydro              225.336082
# CCS Gas                  968.584747
# Nuclear                 1463.950000
# Large Hydro             1650.841597
# Solar Photovoltaics     2268.839378
# Wind Onshore           22452.637137
# Wind Offshore          27031.090000
# Name: p_nom, dtype: float64

# %% [markdown]
# ## System Transformation - 2030

# %%
# scenario = 'Leading The Way'
# scenario = 'Consumer Transformation'
scenario = 'System Transformation'
# scenario = 'Steady Progression'
year = 2030
year_baseline = 2012

start = str(year) + '-12-02 00:00:00'
end = str(year) + '-12-02 00:30:00'
# time step as fraction of hour
time_step = 0.5
data_writer(start, end, time_step, year, demand_dataset='eload', year_baseline=year_baseline,
            scenario=scenario, FES=2022, merge_generators=False, scale_to_peak=True)

df_generators = pd.read_csv('LOPF_data/generators.csv', index_col=0)
buses_scotland = ['Beauly', 'Peterhead', 'Errochty', 'Denny/Bonnybridge', 'Neilston', 'Strathaven', 'Torness', 'Eccles']
# select generators in the buses in Scotland
df_generators_scotland = df_generators[df_generators.bus.isin(buses_scotland)]
generators_p_nom_scotland = df_generators_scotland.p_nom.groupby(
    df_generators_scotland.carrier).sum().sort_values()
if year > 2020:
    generators_p_nom_scotland.drop(['Unmet Load', 'CCS Biomass', 'Natural Gas'], inplace=True)
generators_p_nom_scotland.drop(generators_p_nom_scotland[generators_p_nom_scotland < 50].index, inplace=True)
print(generators_p_nom_scotland)

plt.rcParams.update({'font.size': 22})
# bar chart
plt.figure(figsize=(15,5))
plt.bar(generators_p_nom_scotland.index, generators_p_nom_scotland.values / 1000)
plt.xticks(generators_p_nom_scotland.index, rotation=90)
plt.ylabel('GW')
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
plt.title('Scotland installed generation capacity in year ' + str(year))
plt.show()
# Out:
# c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\core\arrays\datetimes.py:741: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex
#   warnings.warn(
# c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\core\indexing.py:1667: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = value
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB v0.0.1\PyPSA-GB\interconnectors.py:206: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   df_FES = df_FES[~df_FES.Variable.str.contains('(TWh)')]
# carrier
# Oil                       55.200000
# Waste                     82.128000
# Biomass (dedicated)      167.580000
# Small Hydro              222.628043
# CCS Gas                  968.584707
# Solar Photovoltaics     1400.126320
# Large Hydro             1631.002146
# Wind Offshore           5136.090000
# Wind Onshore           18978.428676
# Name: p_nom, dtype: float64

# %% [markdown]
# ## System Transformation - 2021

# %%
# scenario = 'Leading The Way'
# scenario = 'Consumer Transformation'
scenario = 'System Transformation'
# scenario = 'Steady Progression'
year = 2021
year_baseline = 2012

start = str(year) + '-12-02 00:00:00'
end = str(year) + '-12-02 00:30:00'
# time step as fraction of hour
time_step = 0.5
data_writer(start, end, time_step, year, demand_dataset='eload', year_baseline=year_baseline,
            scenario=scenario, FES=2022, merge_generators=False, scale_to_peak=True)

df_generators = pd.read_csv('LOPF_data/generators.csv', index_col=0)
buses_scotland = ['Beauly', 'Peterhead', 'Errochty', 'Denny/Bonnybridge', 'Neilston', 'Strathaven', 'Torness', 'Eccles']
# select generators in the buses in Scotland
df_generators_scotland = df_generators[df_generators.bus.isin(buses_scotland)]
generators_p_nom_scotland = df_generators_scotland.p_nom.groupby(
    df_generators_scotland.carrier).sum().sort_values()
if year > 2020:
    generators_p_nom_scotland.drop(['Unmet Load', 'CCS Biomass'], inplace=True)
generators_p_nom_scotland.drop(generators_p_nom_scotland[generators_p_nom_scotland < 50].index, inplace=True)
print(generators_p_nom_scotland)

plt.rcParams.update({'font.size': 22})
# bar chart
plt.figure(figsize=(15,5))
plt.bar(generators_p_nom_scotland.index, generators_p_nom_scotland.values / 1000)
plt.xticks(generators_p_nom_scotland.index, rotation=90)
plt.ylabel('GW')
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
plt.title('Scotland installed generation capacity in year ' + str(year))
plt.show()
# Out:
# c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\core\arrays\datetimes.py:741: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex
#   warnings.warn(
# c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\core\indexing.py:1667: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = value
# carrier
# Waste                    57.536000
# Biomass (dedicated)     182.476000
# Oil                     197.340000
# Small Hydro             217.124238
# Solar Photovoltaics     462.292021
# Natural Gas            1038.400000
# Large Hydro            1590.680533
# Wind Offshore          1663.100000
# Nuclear                1750.000000
# Wind Onshore           8928.762348
# Name: p_nom, dtype: float64
