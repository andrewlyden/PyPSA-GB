# %%
import os
from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv())
src_path = os.environ.get('PROJECT_SRC')
os.chdir(src_path)

# %%
from data_reader_writer import data_writer

import pypsa

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams.update({'font.size': 22})

# %% [markdown]
# ## System Transformation - 2045

# %%
# scenario = 'Leading The Way'
# scenario = 'Consumer Transformation'
scenario = 'System Transformation'
# scenario = 'Steady Progression'
year = 2045
year_baseline = 2012

start = str(year) + '-01-01 00:00:00'
end = str(year) + '-12-31 23:00:00'
# time step as fraction of hour
time_step = 1
data_writer(start, end, time_step, year, demand_dataset='eload', year_baseline=year_baseline,
            scenario=scenario, FES=2022, merge_generators=True, scale_to_peak=True)
# Out:
# c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\core\arrays\datetimes.py:741: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex
#   warnings.warn(
# c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\core\indexing.py:1667: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = value
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB v0.0.1\PyPSA-GB\interconnectors.py:206: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   df_FES = df_FES[~df_FES.Variable.str.contains('(TWh)')]

# %%
import add_P2G
add_P2G.add_P2G(year, scenario=scenario)

# %%
network = pypsa.Network()
network.import_from_csv_folder('LOPF_data_P2G')
# Out:
# WARNING:pypsa.io:
# Importing PyPSA from older version of PyPSA than current version.
# Please read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html
# carefully to prepare your network for import.
# Currently used PyPSA version [0, 20, 1], imported network file PyPSA version None.
#
# INFO:pypsa.components:Applying weightings to all columns of `snapshot_weightings`
# WARNING:pypsa.io:Components Index(['Tidal lagoon Harker', 'Tidal lagoon Penwortham',
#        'Tidal lagoon S.W.Penisula', 'Tidal stream Deeside',
#        'Tidal stream Lovedean', 'Tidal stream Melksham',
#        'Tidal stream Penwortham', 'Tidal stream S.W.Penisula',
#        'Wave power Beauly', 'Wave power Melksham', 'Wave power Neilston'],
#       dtype='object', name='Generator') for attribute p_max_pu of Generator are not in main components dataframe generators
# INFO:pypsa.io:Imported network LOPF_data_P2G has buses, generators, lines, links, loads, storage_units

# %%
# scale the B6 lines to system transformation economy RT
B6 = network.lines.at['17', 's_nom'] + network.lines.at['18', 's_nom'] + network.lines.at['23', 's_nom'] + network.lines.at['24', 's_nom'] + network.lines.at['16', 's_nom']
# network.lines
scaling_factor = 24666 / B6
network.lines.s_nom *= scaling_factor

# %%
network.lopf(network.snapshots, solver_name="gurobi", pyomo=False)
# Out:
# INFO:pypsa.linopf:Prepare linear problem
# INFO:pypsa.linopf:Total preparation time: 71.72s
# INFO:pypsa.linopf:Solve linear problem using Gurobi solver
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-10-19
# Read LP format model from file C:\Users\alyden\AppData\Local\Temp\pypsa-problem-2zu782cl.lp
# Reading time = 51.16 seconds
# obj: 25298024 rows, 7892761 columns, 44437648 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 25298024 rows, 7892761 columns and 44437648 nonzeros
# Model fingerprint: 0xfed8fd02
# Coefficient statistics:
#   Matrix range     [6e-05, 1e+00]
#   Objective range  [1e+00, 1e+09]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-06, 6e+12]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Presolve removed 23239436 rows and 1337975 columns (presolve time = 5s) ...
# Presolve removed 23246530 rows and 2580000 columns (presolve time = 10s) ...
# Presolve removed 23738756 rows and 3072226 columns (presolve time = 19s) ...
# Presolve removed 23738756 rows and 3072226 columns (presolve time = 21s) ...
# Presolve removed 23791310 rows and 3074673 columns
# Presolve time: 26.83s
# Presolved: 1506714 rows, 4870642 columns, 9311830 nonzeros
#
# Elapsed ordering time = 9s
# Elapsed ordering time = 10s
# Ordering time: 11.39s
#
# Barrier statistics:
#  AA' NZ     : 3.723e+06
#  Factor NZ  : 1.566e+08 (roughly 4.0 GB of memory)
#  Factor Ops : 8.580e+10 (roughly 1 second per iteration)
#  Threads    : 3
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.65880114e+25 -3.36613428e+26  8.08e+10 1.19e+10  9.65e+19    46s
#    1   2.41727836e+25 -1.72735233e+26  7.44e+10 1.15e+10  8.93e+19    51s
#    2   2.23286928e+25 -2.83832199e+26  6.94e+10 1.08e+10  8.67e+19    55s
#    3   1.79292141e+25 -5.39198776e+26  5.63e+10 4.96e+09  8.44e+19    59s
#    4   1.24869263e+25 -2.63761892e+26  3.98e+10 2.65e+09  6.10e+19    64s
#    5   8.82020012e+24 -9.37734749e+25  2.81e+10 1.09e+09  3.96e+19    69s
#    6   4.98668836e+24 -1.77534449e+25  1.58e+10 2.07e+08  2.03e+19    73s
#    7   2.03187894e+24 -3.37223663e+24  6.36e+09 3.57e+07  8.15e+18    77s
#    8   6.88877347e+23 -6.34740358e+23  2.10e+09 5.64e+06  2.72e+18    81s
#    9   2.21273781e+23 -1.50962516e+23  6.41e+08 1.33e+06  8.43e+17    84s
#   10   5.69191277e+22 -3.96073395e+22  3.18e+08 4.93e+05  1.99e+17    88s
#   11   2.65880114e+25 -3.36613428e+26  8.08e+10 1.19e+10  9.65e+19    95s
#   12   4.26128582e+25 -3.01028621e+26  7.50e+10 1.11e+10  1.80e+20   100s
#   13   3.52006093e+25 -2.18434047e+26  5.21e+10 8.07e+09  2.41e+20   104s
#   14   1.81792181e+25 -9.40655006e+25  2.64e+10 3.46e+09  1.73e+20   107s
#   15   6.42376054e+24 -2.72998269e+25  9.37e+09 9.99e+08  6.76e+19   111s
#   16   1.46408326e+24 -3.38316420e+24  2.13e+09 1.24e+08  1.52e+19   114s
#   17   2.16412977e+23 -3.04380343e+23  3.00e+08 1.15e+07  2.11e+18   119s
#   18   5.09218918e+22 -6.53212379e+22  2.26e+08 2.52e+06  4.90e+17   125s
#   19   1.04362325e+22 -1.87609421e+22  4.16e+07 7.30e+05  1.04e+17   130s
#   20   2.47594406e+21 -5.02377949e+21  9.71e+06 1.95e+05  2.67e+16   135s
#   21   4.97666002e+20 -1.86175264e+21  1.96e+06 7.28e+04  5.60e+15   139s
#   22   2.15921136e+19 -9.18751516e+19  9.10e+04 3.49e+03  2.38e+14   143s
#   23   1.81611315e+18 -1.48610330e+19  1.10e+04 5.37e+02  9.31e+12   148s
#   24   2.30239874e+17 -3.41989757e+18  2.33e+03 1.19e+02  1.02e+12   152s
#   25   3.95575600e+16 -1.49807384e+18  5.67e+02 5.16e+01  2.51e+11   159s
#   26   5.05142875e+15 -8.31372199e+17  1.52e+02 2.86e+01  1.02e+11   165s
#   27   7.16643581e+14 -6.77314283e+16  2.76e+01 2.33e+00  7.20e+09   173s
#   28   2.35968218e+12 -5.79866965e+14  1.49e+00 1.97e-02  5.98e+07   181s
#   29   5.66250719e+10 -8.54464863e+12  1.20e+00 2.94e-04  8.83e+05   189s
#   30   4.48641337e+10 -2.26038940e+12  3.43e-01 8.82e-05  2.37e+05   203s
#   31   2.73111739e+10 -5.23812603e+11  1.35e-01 2.41e-05  5.66e+04   217s
#   32   1.77370670e+10 -2.30307096e+11  3.89e-02 1.75e-05  2.55e+04   229s
#   33   1.37913986e+10 -1.24173238e+11  2.31e-02 1.21e-05  1.42e+04   238s
#   34   9.18156439e+09 -6.81214919e+10  1.01e-02 1.13e-05  7.94e+03   250s
#   35   6.62686175e+09 -4.11990300e+10  5.08e-03 7.75e-06  4.91e+03   263s
#   36   5.01245531e+09 -2.93470698e+10  2.69e-03 9.45e-06  3.53e+03   274s
#   37   4.23187603e+09 -1.22895224e+10  1.75e-03 5.65e-06  1.70e+03   288s
#   38   3.84975165e+09 -7.99532137e+09  1.40e-03 5.61e-06  1.22e+03   300s
#   39   3.50353767e+09 -5.00075401e+09  1.11e-03 7.42e-06  8.73e+02   310s
#   40   3.24350075e+09 -3.10451839e+09  9.05e-04 5.52e-06  6.52e+02   322s
#   41   2.97958760e+09 -1.21288617e+09  7.10e-04 5.50e-06  4.30e+02   336s
#   42   2.65406371e+09 -4.18619866e+08  4.79e-04 5.53e-06  3.15e+02   352s
#   43   2.50998925e+09  5.65798586e+07  3.88e-04 7.38e-06  2.52e+02   369s
#   44   2.33151840e+09  4.86916341e+08  2.77e-04 7.41e-06  1.89e+02   386s
#   45   2.22745172e+09  8.93222240e+08  2.16e-04 3.67e-06  1.37e+02   403s
#   46   2.16240408e+09  1.12614618e+09  1.79e-04 5.50e-06  1.06e+02   420s
#   47   2.11736114e+09  1.24182870e+09  1.54e-04 3.66e-06  8.99e+01   427s
#   48   2.05280140e+09  1.34699369e+09  1.16e-04 1.84e-06  7.25e+01   434s
#   49   2.01782601e+09  1.45700885e+09  9.71e-05 1.83e-06  5.76e+01   441s
#   50   1.99378622e+09  1.51951656e+09  8.40e-05 3.67e-06  4.87e+01   448s
#   51   1.97044228e+09  1.58840242e+09  7.14e-05 5.50e-06  3.92e+01   455s
#   52   1.95501347e+09  1.62620679e+09  6.32e-05 5.50e-06  3.38e+01   461s
#   53   1.93994462e+09  1.65686220e+09  5.52e-05 4.20e-06  2.91e+01   469s
#   54   1.91789735e+09  1.68607510e+09  4.31e-05 4.14e-06  2.38e+01   476s
#   55   1.90797771e+09  1.70580517e+09  3.79e-05 2.24e-06  2.08e+01   482s
#   56   1.89921787e+09  1.72669679e+09  3.31e-05 3.69e-06  1.77e+01   490s
#   57   1.89191104e+09  1.74234341e+09  2.93e-05 3.71e-06  1.54e+01   497s
#   58   1.88691478e+09  1.75249228e+09  2.66e-05 7.43e-06  1.38e+01   504s
#   59   1.87972679e+09  1.76291495e+09  2.26e-05 7.42e-06  1.20e+01   511s
#   60   1.87225668e+09  1.77504461e+09  1.86e-05 5.59e-06  9.98e+00   518s
#   61   1.86900278e+09  1.78193431e+09  1.68e-05 7.64e-06  8.94e+00   525s
#   62   1.86469083e+09  1.78837249e+09  1.45e-05 7.50e-06  7.83e+00   532s
#   63   1.86165470e+09  1.79536163e+09  1.28e-05 5.74e-06  6.81e+00   539s
#   64   1.85911362e+09  1.80383337e+09  1.14e-05 7.48e-06  5.67e+00   547s
#   65   1.85685257e+09  1.80823795e+09  1.02e-05 9.35e-06  4.99e+00   554s
#   66   1.85362736e+09  1.81305989e+09  8.48e-06 9.35e-06  4.16e+00   561s
#   67   1.85043403e+09  1.81689202e+09  6.77e-06 5.70e-06  3.44e+00   568s
#   68   1.84909708e+09  1.82069109e+09  6.02e-06 7.50e-06  2.92e+00   574s
#   69   1.84799452e+09  1.82300409e+09  5.42e-06 5.67e-06  2.57e+00   581s
#   70   1.84668298e+09  1.82598091e+09  4.73e-06 5.69e-06  2.13e+00   588s
#   71   1.84498640e+09  1.82746864e+09  3.78e-06 3.81e-06  1.80e+00   595s
#   72   1.84388134e+09  1.82878301e+09  3.18e-06 5.70e-06  1.55e+00   601s
#   73   1.84312481e+09  1.83035009e+09  2.75e-06 5.69e-06  1.31e+00   608s
#   74   1.84272246e+09  1.83148531e+09  2.53e-06 5.68e-06  1.15e+00   615s
#   75   1.84217375e+09  1.83250882e+09  2.23e-06 3.79e-06  9.92e-01   622s
#   76   1.84148532e+09  1.83337022e+09  1.88e-06 3.83e-06  8.33e-01   629s
#   77   1.84107342e+09  1.83379338e+09  1.66e-06 3.84e-06  7.47e-01   636s
#   78   1.84091777e+09  1.83438084e+09  1.57e-06 3.84e-06  6.71e-01   643s
#   79   1.84053949e+09  1.83482560e+09  1.36e-06 3.85e-06  5.87e-01   649s
#   80   1.84008478e+09  1.83528868e+09  1.12e-06 5.78e-06  4.92e-01   657s
#   81   1.83980450e+09  1.83586671e+09  9.63e-07 7.70e-06  4.04e-01   664s
#   82   1.83949728e+09  1.83634297e+09  7.90e-07 5.76e-06  3.24e-01   671s
#   83   1.83922286e+09  1.83666552e+09  6.28e-07 5.77e-06  2.63e-01   679s
#   84   1.83906089e+09  1.83684497e+09  5.35e-07 3.84e-06  2.28e-01   686s
#   85   1.83888205e+09  1.83704666e+09  4.37e-07 5.76e-06  1.88e-01   693s
#   86   1.83872109e+09  1.83727647e+09  3.91e-07 3.85e-06  1.48e-01   698s
#   87   1.83860869e+09  1.83741152e+09  3.33e-07 5.78e-06  1.23e-01   705s
#   88   1.83852150e+09  1.83754124e+09  3.15e-07 5.79e-06  1.01e-01   712s
#   89   1.83845430e+09  1.83766464e+09  2.97e-07 5.79e-06  8.11e-02   718s
#   90   1.83841090e+09  1.83774645e+09  2.83e-07 5.78e-06  6.83e-02   725s
#   91   1.83837458e+09  1.83781318e+09  2.57e-07 7.71e-06  5.77e-02   731s
#   92   1.83833683e+09  1.83789052e+09  2.97e-07 5.76e-06  4.59e-02   737s
#   93   1.83828801e+09  1.83796605e+09  5.92e-07 5.79e-06  3.31e-02   743s
#   94   1.83825437e+09  1.83800207e+09  6.64e-07 5.81e-06  2.60e-02   749s
#   95   1.83823390e+09  1.83802545e+09  8.85e-07 5.79e-06  2.15e-02   754s
#   96   1.83821864e+09  1.83804184e+09  8.37e-07 7.73e-06  1.82e-02   760s
#   97   1.83820751e+09  1.83805820e+09  1.78e-06 5.78e-06  1.54e-02   764s
#   98   1.83820049e+09  1.83807274e+09  1.34e-06 7.71e-06  1.32e-02   769s
#   99   1.83818642e+09  1.83807886e+09  1.46e-06 7.69e-06  1.11e-02   775s
#  100   1.83817668e+09  1.83809186e+09  1.20e-06 7.65e-06  8.74e-03   784s
#  101   1.83816613e+09  1.83809886e+09  9.11e-07 9.51e-06  6.93e-03   793s
#  102   1.83816107e+09  1.83810790e+09  7.74e-07 7.61e-06  5.48e-03   804s
#  103   1.83815511e+09  1.83811337e+09  6.08e-07 9.47e-06  4.30e-03   814s
#  104   1.83815188e+09  1.83811712e+09  5.20e-07 9.46e-06  3.58e-03   824s
#  105   1.83814842e+09  1.83812061e+09  4.25e-07 9.45e-06  2.87e-03   834s
#  106   1.83814509e+09  1.83812450e+09  3.32e-07 9.43e-06  2.12e-03   843s
#  107   1.83814284e+09  1.83812652e+09  2.71e-07 7.58e-06  1.68e-03   852s
#  108   1.83814136e+09  1.83812684e+09  2.30e-07 9.48e-06  1.50e-03   861s
#  109   1.83814064e+09  1.83812846e+09  2.13e-07 9.61e-06  1.25e-03   870s
#  110   1.83813944e+09  1.83812987e+09  1.78e-07 7.69e-06  9.79e-04   879s
#  111   1.83813830e+09  1.83813062e+09  1.45e-07 9.66e-06  7.84e-04   890s
#  112   1.83813682e+09  1.83813141e+09  1.02e-07 7.74e-06  5.52e-04   899s
#  113   1.83813595e+09  1.83813188e+09  7.62e-08 7.72e-06  4.14e-04   908s
#  114   1.83813520e+09  1.83813241e+09  5.92e-08 7.71e-06  2.85e-04   919s
#  115   1.83813483e+09  1.83813273e+09  1.12e-07 9.76e-06  2.14e-04   929s
#  116   1.83813446e+09  1.83813299e+09  3.63e-07 7.81e-06  1.49e-04   937s
#  117   1.83813412e+09  1.83813312e+09  2.77e-07 5.86e-06  1.01e-04   945s
#  118   1.83813389e+09  1.83813324e+09  2.12e-07 7.80e-06  6.62e-05   954s
#  119   1.83813371e+09  1.83813334e+09  7.22e-07 3.89e-06  3.85e-05   962s
#  120   1.83813362e+09  1.83813337e+09  9.92e-07 5.51e-06  2.57e-05   969s
#  121   1.83813357e+09  1.83813338e+09  5.43e-06 7.11e-06  1.87e-05   976s
#  122   1.83813353e+09  1.83813339e+09  3.93e-06 7.80e-06  1.37e-05   984s
#  123   1.83813351e+09  1.83813340e+09  3.00e-06 6.17e-06  1.05e-05   990s
#  124   1.83813349e+09  1.83813341e+09  2.51e-06 9.74e-06  8.41e-06   997s
#  125   1.83813346e+09  1.83813342e+09  1.73e-06 8.70e-06  3.98e-06  1004s
#  126   1.83813344e+09  1.83813342e+09  5.76e-06 1.12e-05  2.00e-06  1012s
#  127   1.83813343e+09  1.83813342e+09  3.53e-06 1.56e-05  1.04e-06  1019s
#  128   1.83813343e+09  1.83813343e+09  5.46e-06 1.59e-05  3.49e-07  1026s
#  129   1.83813343e+09  1.83813343e+09  1.69e-05 1.08e-05  1.28e-07  1032s
#  130   1.83813343e+09  1.83813343e+09  8.34e-06 1.37e-05  6.03e-08  1038s
#  131   1.83813343e+09  1.83813343e+09  1.76e-06 7.79e-06  7.52e-09  1044s
#
# Barrier solved model in 131 iterations and 1044.02 seconds (831.05 work units)
# Optimal objective 1.83813343e+09
#
# Crossover log...
#
#   229580 DPushes remaining with DInf 0.0000000e+00              1049s
#    33239 DPushes remaining with DInf 0.0000000e+00              1054s
#     4504 DPushes remaining with DInf 0.0000000e+00              1058s
#      147 DPushes remaining with DInf 0.0000000e+00              1060s
#        0 DPushes remaining with DInf 0.0000000e+00              1061s
#
#   711058 PPushes remaining with PInf 7.4225868e-03              1062s
#   501249 PPushes remaining with PInf 9.7390829e-03              1087s
#   426939 PPushes remaining with PInf 8.5807476e-03              1092s
#   387398 PPushes remaining with PInf 8.6856853e-03              1096s
#   362256 PPushes remaining with PInf 8.2894876e-03              1100s
#   329722 PPushes remaining with PInf 7.0280630e-03              1107s
#   317840 PPushes remaining with PInf 5.9791914e-03              1110s
#   298284 PPushes remaining with PInf 5.5795371e-03              1116s
#   282493 PPushes remaining with PInf 5.3874326e-03              1122s
#   269915 PPushes remaining with PInf 5.1139504e-03              1126s
#   257864 PPushes remaining with PInf 5.0424949e-03              1131s
#   247545 PPushes remaining with PInf 4.2711223e-03              1136s
#   238759 PPushes remaining with PInf 4.2509277e-03              1141s
#   230887 PPushes remaining with PInf 4.1474396e-03              1147s
#   223733 PPushes remaining with PInf 4.1009425e-03              1151s
#   216889 PPushes remaining with PInf 3.5295350e-03              1156s
#   210307 PPushes remaining with PInf 3.5283926e-03              1160s
#   202153 PPushes remaining with PInf 3.3196283e-03              1167s
#   197029 PPushes remaining with PInf 2.0207884e-03              1171s
#   191990 PPushes remaining with PInf 2.0207885e-03              1175s
#   184494 PPushes remaining with PInf 1.5912298e-03              1182s
#   179851 PPushes remaining with PInf 1.5912298e-03              1186s
#   173290 PPushes remaining with PInf 1.5912296e-03              1192s
#   169234 PPushes remaining with PInf 1.5912297e-03              1196s
#   165191 PPushes remaining with PInf 1.5535144e-03              1200s
#   159588 PPushes remaining with PInf 1.5535145e-03              1207s
#   156100 PPushes remaining with PInf 1.5535145e-03              1211s
#   150776 PPushes remaining with PInf 1.5521596e-03              1217s
#   147267 PPushes remaining with PInf 1.5521595e-03              1221s
#   144065 PPushes remaining with PInf 1.5521596e-03              1225s
#   139734 PPushes remaining with PInf 1.2119375e-03              1232s
#   136237 PPushes remaining with PInf 1.2119374e-03              1238s
#   132755 PPushes remaining with PInf 1.2043755e-03              1242s
#   130009 PPushes remaining with PInf 1.2043756e-03              1246s
#   127262 PPushes remaining with PInf 1.2003567e-03              1250s
#   123271 PPushes remaining with PInf 1.2003567e-03              1256s
#   121453 PPushes remaining with PInf 1.2003569e-03              1260s
#   118455 PPushes remaining with PInf 1.2003567e-03              1265s
#   114534 PPushes remaining with PInf 1.2003566e-03              1271s
#   112806 PPushes remaining with PInf 1.2003567e-03              1275s
# Warning: 1 variables dropped from basis
#
# Restart crossover...
#
#   831829 variables added to crossover basis                     1283s
#
#   240815 DPushes remaining with DInf 0.0000000e+00              1287s
#    36602 DPushes remaining with DInf 0.0000000e+00              1293s
#     6980 DPushes remaining with DInf 0.0000000e+00              1297s
#     1309 DPushes remaining with DInf 0.0000000e+00              1301s
#        0 DPushes remaining with DInf 0.0000000e+00              1306s
#
#   716162 PPushes remaining with PInf 4.0277238e-02              1306s
#   526890 PPushes remaining with PInf 4.7055440e-02              1334s
#   452294 PPushes remaining with PInf 3.1892008e-02              1341s
#   414568 PPushes remaining with PInf 2.2551312e-02              1346s
#   389908 PPushes remaining with PInf 2.3175446e-02              1352s
#   372275 PPushes remaining with PInf 1.9386615e-02              1355s
#   345365 PPushes remaining with PInf 1.0295592e-02              1363s
#   334344 PPushes remaining with PInf 1.0465047e-02              1367s
#   324983 PPushes remaining with PInf 1.0793995e-02              1371s
#   309721 PPushes remaining with PInf 7.2010074e-03              1377s
#   302897 PPushes remaining with PInf 7.3233253e-03              1381s
#   291732 PPushes remaining with PInf 6.3956935e-03              1386s
#   281691 PPushes remaining with PInf 6.1359007e-03              1393s
#   277014 PPushes remaining with PInf 5.8240119e-03              1396s
#   268679 PPushes remaining with PInf 5.1980528e-03              1402s
#   260922 PPushes remaining with PInf 4.3413571e-03              1408s
#   256720 PPushes remaining with PInf 4.2626153e-03              1411s
#   249803 PPushes remaining with PInf 4.2021196e-03              1416s
#   243513 PPushes remaining with PInf 3.7453407e-03              1421s
#   237334 PPushes remaining with PInf 3.6498747e-03              1426s
#   231427 PPushes remaining with PInf 3.2822231e-03              1431s
#   226080 PPushes remaining with PInf 3.2839363e-03              1436s
#   220749 PPushes remaining with PInf 3.2316888e-03              1441s
#   215961 PPushes remaining with PInf 2.7439544e-03              1446s
#   211479 PPushes remaining with PInf 2.6993660e-03              1450s
#   205390 PPushes remaining with PInf 2.6894899e-03              1457s
#   201258 PPushes remaining with PInf 2.6746339e-03              1462s
#   197051 PPushes remaining with PInf 2.6726197e-03              1466s
#   193349 PPushes remaining with PInf 2.6726196e-03              1471s
#   189765 PPushes remaining with PInf 2.6726196e-03              1476s
#   186392 PPushes remaining with PInf 2.6726196e-03              1480s
#   182628 PPushes remaining with PInf 2.6467443e-03              1486s
#   179208 PPushes remaining with PInf 2.6437676e-03              1491s
#   175949 PPushes remaining with PInf 2.6437676e-03              1496s
#   172770 PPushes remaining with PInf 2.6362055e-03              1501s
#   169640 PPushes remaining with PInf 2.5325838e-03              1506s
#   166541 PPushes remaining with PInf 2.5305762e-03              1511s
#   165066 PPushes remaining with PInf 2.5305762e-03              1515s
#   162280 PPushes remaining with PInf 1.2446050e-03              1520s
#   159510 PPushes remaining with PInf 1.2446050e-03              1525s
#   154333 PPushes remaining with PInf 1.2446050e-03              1535s
#   153125 PPushes remaining with PInf 1.2432501e-03              1537s
#   151125 PPushes remaining with PInf 1.2432501e-03              1541s
#   149243 PPushes remaining with PInf 1.2432501e-03              1546s
#   147556 PPushes remaining with PInf 1.2432501e-03              1551s
#   145681 PPushes remaining with PInf 1.2432501e-03              1557s
#   143705 PPushes remaining with PInf 1.1815234e-03              1561s
#   141853 PPushes remaining with PInf 1.1815234e-03              1567s
#   140163 PPushes remaining with PInf 1.1815234e-03              1572s
#   138542 PPushes remaining with PInf 1.1815233e-03              1578s
#   136814 PPushes remaining with PInf 4.6372977e-04              1582s
#   134987 PPushes remaining with PInf 4.6372976e-04              1588s
#   133952 PPushes remaining with PInf 4.6372976e-04              1591s
#   131746 PPushes remaining with PInf 4.6372976e-04              1596s
#   129855 PPushes remaining with PInf 4.6372977e-04              1601s
#   128319 PPushes remaining with PInf 4.6372980e-04              1607s
#   126581 PPushes remaining with PInf 4.6372978e-04              1612s
#   124862 PPushes remaining with PInf 4.6372980e-04              1617s
#   123163 PPushes remaining with PInf 4.6372981e-04              1623s
#   121234 PPushes remaining with PInf 4.6372975e-04              1629s
#   120354 PPushes remaining with PInf 4.6372978e-04              1633s
#   119585 PPushes remaining with PInf 4.6372979e-04              1637s
#   118654 PPushes remaining with PInf 4.6372978e-04              1640s
#   116562 PPushes remaining with PInf 4.6372977e-04              1647s
#   114703 PPushes remaining with PInf 4.6245839e-04              1653s
#   113648 PPushes remaining with PInf 4.6245838e-04              1655s
#   111202 PPushes remaining with PInf 4.6245839e-04              1662s
#   109263 PPushes remaining with PInf 2.7808224e-04              1667s
#   107413 PPushes remaining with PInf 2.7808220e-04              1671s
#   105678 PPushes remaining with PInf 2.7808220e-04              1675s
#   103121 PPushes remaining with PInf 5.2902748e-05              1681s
#   101122 PPushes remaining with PInf 5.2902750e-05              1686s
#    99163 PPushes remaining with PInf 1.1200080e-06              1690s
#    97384 PPushes remaining with PInf 1.1200080e-06              1697s
#    95669 PPushes remaining with PInf 1.1200080e-06              1702s
#    93727 PPushes remaining with PInf 1.1200080e-06              1707s
#    92609 PPushes remaining with PInf 1.1200080e-06              1710s
#    90727 PPushes remaining with PInf 1.1200080e-06              1716s
#    88586 PPushes remaining with PInf 1.1200080e-06              1722s
#    87373 PPushes remaining with PInf 1.1200080e-06              1725s
#    84555 PPushes remaining with PInf 1.1200080e-06              1733s
#    83544 PPushes remaining with PInf 1.1200080e-06              1735s
#    81624 PPushes remaining with PInf 1.1200080e-06              1740s
# Warning: 1 variables dropped from basis
#    79809 PPushes remaining with PInf 6.5739916e+03              1748s
#    78988 PPushes remaining with PInf 2.6856907e+03              1753s
#    78088 PPushes remaining with PInf 2.4679609e+03              1757s
#    77049 PPushes remaining with PInf 2.4679609e+03              1760s
#    75377 PPushes remaining with PInf 2.4679609e+03              1766s
#    73469 PPushes remaining with PInf 2.4679609e+03              1771s
#    71750 PPushes remaining with PInf 2.4679609e+03              1776s
#    69826 PPushes remaining with PInf 2.4679609e+03              1781s
#    67751 PPushes remaining with PInf 2.4679609e+03              1786s
# Warning: 14 variables dropped from basis
#    66014 PPushes remaining with PInf 7.6312665e+10              1793s
#    65107 PPushes remaining with PInf 7.6312665e+10              1795s
#    63120 PPushes remaining with PInf 7.6312665e+10              1801s
#    61191 PPushes remaining with PInf 7.6312665e+10              1806s
#    59076 PPushes remaining with PInf 7.6312665e+10              1812s
#    57032 PPushes remaining with PInf 7.6312665e+10              1817s
#    55294 PPushes remaining with PInf 7.6312665e+10              1822s
#    54328 PPushes remaining with PInf 7.6312665e+10              1826s
#    52420 PPushes remaining with PInf 7.6312665e+10              1830s
#    49798 PPushes remaining with PInf 7.6312665e+10              1836s
#    47947 PPushes remaining with PInf 7.6312665e+10              1841s
#    45993 PPushes remaining with PInf 7.6312665e+10              1846s
#    44102 PPushes remaining with PInf 7.6312665e+10              1852s
#    42330 PPushes remaining with PInf 7.6312665e+10              1858s
#    41438 PPushes remaining with PInf 7.6312665e+10              1861s
#    39691 PPushes remaining with PInf 7.6312665e+10              1868s
#    38753 PPushes remaining with PInf 7.6312665e+10              1872s
#    36972 PPushes remaining with PInf 7.6312665e+10              1877s
#    36032 PPushes remaining with PInf 7.6312665e+10              1881s
#    34459 PPushes remaining with PInf 7.6312665e+10              1887s
#    33449 PPushes remaining with PInf 7.6261735e+10              1890s
#    32107 PPushes remaining with PInf 7.6254291e+10              1895s
#    30255 PPushes remaining with PInf 7.6254291e+10              1902s
#    29024 PPushes remaining with PInf 4.7505919e+10              1907s
#    27790 PPushes remaining with PInf 4.7505840e+10              1912s
#    27165 PPushes remaining with PInf 4.7505840e+10              1915s
#    25940 PPushes remaining with PInf 4.7505839e+10              1921s
#    24725 PPushes remaining with PInf 4.7505839e+10              1926s
#    23511 PPushes remaining with PInf 4.7505839e+10              1932s
#    22303 PPushes remaining with PInf 4.7505839e+10              1936s
#    21097 PPushes remaining with PInf 4.7505839e+10              1942s
#    19891 PPushes remaining with PInf 4.7505839e+10              1947s
#    18685 PPushes remaining with PInf 4.7505839e+10              1951s
#    17478 PPushes remaining with PInf 4.7505839e+10              1955s
#    15669 PPushes remaining with PInf 4.7505839e+10              1961s
#    14463 PPushes remaining with PInf 4.7505839e+10              1965s
#    12522 PPushes remaining with PInf 3.2741996e+10              1971s
#    11280 PPushes remaining with PInf 3.2741996e+10              1975s
#     9407 PPushes remaining with PInf 3.2741996e+10              1982s
#     8146 PPushes remaining with PInf 3.2741996e+10              1986s
#     6892 PPushes remaining with PInf 3.2690440e+10              1990s
#     5042 PPushes remaining with PInf 3.2690440e+10              1997s
#     3795 PPushes remaining with PInf 3.2690440e+10              2001s
#     1984 PPushes remaining with PInf 3.2690440e+10              2007s
#      777 PPushes remaining with PInf 3.2690440e+10              2011s
#        0 PPushes remaining with PInf 3.2497738e+10              2016s
#
#   Push phase complete: Pinf 3.2497738e+10, Dinf 5.2112922e-01   2016s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   951875    1.8381334e+09   0.000000e+00   5.211292e-01   2019s
#   952005    1.8381334e+09   1.718254e+10   0.000000e+00   2022s
#   953993    1.8381334e+09   6.759841e+03   0.000000e+00   2027s
#   954382    1.8381334e+09   0.000000e+00   0.000000e+00   2050s
#
# Solved with barrier
# Solved in 954382 iterations and 2051.16 seconds (1948.47 work units)
# Optimal objective  1.838133426e+09
# INFO:pypsa.linopf:Optimization successful. Objective value: 1.84e+09
# ('ok', 'optimal')

# %%
p_by_carrier = network.generators_t.p.groupby(
    network.generators.carrier, axis=1).sum()

storage_by_carrier = network.storage_units_t.p.groupby(
    network.storage_units.carrier, axis=1).sum()

# to show on graph set the negative storage values to zero
storage_by_carrier[storage_by_carrier < 0] = 0

p_by_carrier = pd.concat([p_by_carrier, storage_by_carrier], axis=1)

# group biomass stuff
p_by_carrier['Biomass'] = (
    p_by_carrier['Biomass (dedicated)'] + p_by_carrier['Biomass (co-firing)'])

# rename the hydro bit
p_by_carrier = p_by_carrier.rename(
    columns={'Large Hydro': 'Hydro'})

p_by_carrier
# Out:
# carrier              Biomass (co-firing)  Biomass (dedicated)  CCS Biomass  \
# snapshot
# 2045-01-01 00:00:00                  0.0                  0.0          0.0
# 2045-01-01 01:00:00                  0.0                  0.0          0.0
# 2045-01-01 02:00:00                  0.0                  0.0          0.0
# 2045-01-01 03:00:00                  0.0                  0.0          0.0
# 2045-01-01 04:00:00                  0.0                  0.0          0.0
# ...                                  ...                  ...          ...
# 2045-12-31 19:00:00                  0.0                  0.0          0.0
# 2045-12-31 20:00:00                  0.0                  0.0          0.0
# 2045-12-31 21:00:00                  0.0                  0.0          0.0
# 2045-12-31 22:00:00                  0.0                  0.0          0.0
# 2045-12-31 23:00:00                  0.0                  0.0          0.0
#
# carrier              CCS Gas  Coal  Hydrogen       Hydro  Natural Gas  \
# snapshot
# 2045-01-01 00:00:00      0.0   0.0       0.0  321.719175          0.0
# 2045-01-01 01:00:00      0.0   0.0       0.0  301.978920          0.0
# 2045-01-01 02:00:00      0.0   0.0       0.0  301.743915          0.0
# 2045-01-01 03:00:00      0.0   0.0       0.0  417.107943          0.0
# 2045-01-01 04:00:00      0.0   0.0       0.0  421.574456          0.0
# ...                      ...   ...       ...         ...          ...
# 2045-12-31 19:00:00      0.0   0.0       0.0  570.822408          0.0
# 2045-12-31 20:00:00      0.0   0.0       0.0  537.686978          0.0
# 2045-12-31 21:00:00      0.0   0.0       0.0  483.401273          0.0
# 2045-12-31 22:00:00      0.0   0.0       0.0  601.365161          0.0
# 2045-12-31 23:00:00      0.0   0.0       0.0  461.075983          0.0
#
# carrier              Nuclear  Oil  ...  Waste  Wave power  Wind Offshore  \
# snapshot                           ...
# 2045-01-01 00:00:00      0.0  0.0  ...    0.0     0.00000   67403.555315
# 2045-01-01 01:00:00      0.0  0.0  ...    0.0    13.99714   64135.967713
# 2045-01-01 02:00:00      0.0  0.0  ...    0.0    13.99714   63445.272784
# 2045-01-01 03:00:00      0.0  0.0  ...    0.0    13.99714   67449.325421
# 2045-01-01 04:00:00      0.0  0.0  ...    0.0    13.99714   63944.294450
# ...                      ...  ...  ...    ...         ...            ...
# 2045-12-31 19:00:00      0.0  0.0  ...    0.0    16.62686   70243.669008
# 2045-12-31 20:00:00      0.0  0.0  ...    0.0    16.62686   72795.218389
# 2045-12-31 21:00:00      0.0  0.0  ...    0.0    16.62686   69298.483492
# 2045-12-31 22:00:00      0.0  0.0  ...    0.0    16.62686   61255.530317
# 2045-12-31 23:00:00      0.0  0.0  ...    0.0    16.62686   57735.920723
#
# carrier              Wind Onshore      Battery  Compressed Air  Liquid Air  \
# snapshot
# 2045-01-01 00:00:00  14373.634088     0.000000         0.00000    0.000000
# 2045-01-01 01:00:00  15693.597602     0.000000         0.00000    0.000000
# 2045-01-01 02:00:00  15769.358078     0.000000         0.00000    0.000000
# 2045-01-01 03:00:00  13850.432096     0.000000         0.00000    0.000000
# 2045-01-01 04:00:00  13620.503899     0.000000         0.00000    0.000000
# ...                           ...          ...             ...         ...
# 2045-12-31 19:00:00  12760.926755  4105.759287       797.16734    8.445491
# 2045-12-31 20:00:00  11193.476853  2900.154914         0.00000    0.000000
# 2045-12-31 21:00:00  11548.596679  1911.461593         0.00000    0.000000
# 2045-12-31 22:00:00  13017.745489     0.000000         0.00000    0.000000
# 2045-12-31 23:00:00  13995.719480     0.000000         0.00000    0.000000
#
# carrier              P2G  Pumped Storage Hydroelectric  Biomass
# snapshot
# 2045-01-01 00:00:00  0.0                      0.000000      0.0
# 2045-01-01 01:00:00  0.0                      0.000000      0.0
# 2045-01-01 02:00:00  0.0                      0.000000      0.0
# 2045-01-01 03:00:00  0.0                      0.000000      0.0
# 2045-01-01 04:00:00  0.0                      0.000000      0.0
# ...                  ...                           ...      ...
# 2045-12-31 19:00:00  0.0                   2103.900000      0.0
# 2045-12-31 20:00:00  0.0                   1288.224324      0.0
# 2045-12-31 21:00:00  0.0                   1271.238774      0.0
# 2045-12-31 22:00:00  0.0                      0.000000      0.0
# 2045-12-31 23:00:00  0.0                    506.234053      0.0
#
# [8760 rows x 25 columns]

# %%
cols = ["Nuclear", 'Biomass',
        'Waste', "Oil", "Natural Gas",
        'Hydrogen', 'CCS Gas', 'CCS Biomass',
        "Pumped Storage Hydroelectric", 'Hydro',
        'Battery', 'Compressed Air', 'Liquid Air',
        "Wind Offshore", 'Wind Onshore', 'Solar Photovoltaics',
        'Unmet Load'
        ]

p_by_carrier = p_by_carrier[cols]

p_by_carrier.drop(
    (p_by_carrier.max()[p_by_carrier.max() < 50.0]).index,
    axis=1, inplace=True)


colors = {"Coal": "grey",
          "Diesel/Gas oil": "black",
          "Diesel/gas Diesel/Gas oil": "black",
          'Oil': 'black',
          'Unmet Load': 'black',
          'Anaerobic Digestion': 'green',
          'Waste': 'chocolate',
          'Sewage Sludge Digestion': 'green',
          'Landfill Gas': 'green',
          'Biomass (dedicated)': 'green',
          'Biomass (co-firing)': 'green',
          'Biomass': 'green',
          'CCS Biomass': 'darkgreen',
          'Interconnectors Import': 'pink',
          "Sour gas": "lightcoral",
          "Natural Gas": "lightcoral",
          'CCS Gas': "lightcoral",
          'Hydrogen': "deeppink",
          "Nuclear": "orange",
          'Shoreline Wave': 'aqua',
          'Tidal Barrage and Tidal Stream': 'aqua',
          'Hydro': "turquoise",
          "Large Hydro": "turquoise",
          "Small Hydro": "turquoise",
          "Pumped Storage Hydroelectric": "darkturquoise",
          'Battery': 'lime',
          'Compressed Air': 'greenyellow',
          'Liquid Air': 'lawngreen',
          "Wind Offshore": "lightskyblue",
          'Wind Onshore': 'deepskyblue',
          'Solar Photovoltaics': 'yellow'}

fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15,10)
(p_by_carrier / 1e3).plot(
    kind="area", ax=ax, linewidth=0,
    color=[colors[col] for col in p_by_carrier.columns])

# Shrink current axis's height by 10% on the bottom
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])
plt.axvline(x = '2045-12-07 20:00:00', color = 'black', label = 'Peak GB demand')
# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=True, ncol=3)

ax.set_ylabel("GW")

ax.set_xlabel("")
# Out:
# Text(0.5, 0, '')

# %%
start = str(year) + '-12-07 00:00:00'
end = str(year) + '-12-08 23:30:00'
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15,10)
(p_by_carrier / 1e3)[start:end].plot(
    kind="area", ax=ax, linewidth=0,
    color=[colors[col] for col in p_by_carrier.columns])

# Shrink current axis's height by 10% on the bottom
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])
plt.axvline(x = '2045-12-07 20:00:00', color = 'black', label = 'Peak Scotland demand')
# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=True, ncol=3)
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
#           fancybox=True, shadow=True, ncol=5)
ax.set_ylabel("GW")

ax.set_xlabel("")
# Out:
# Text(0.5, 0, '')

# %%
buses_scotland = ['Beauly', 'Peterhead', 'Errochty', 'Denny/Bonnybridge', 'Neilston', 'Strathaven', 'Torness', 'Eccles']
df_generators_scotland = network.generators[network.generators.bus.isin(buses_scotland)]
df_storage_scotland = network.storage_units[network.storage_units.bus.isin(buses_scotland)]

p_by_carrier_scotland = network.generators_t.p[df_generators_scotland.index.values].groupby(
    network.generators.carrier, axis=1).sum()

storage_by_carrier_scotland = network.storage_units_t.p[df_storage_scotland.index.values].groupby(
    network.storage_units.carrier, axis=1).sum()

# to show on graph set the negative storage values to zero
storage_by_carrier_scotland[storage_by_carrier_scotland < 0] = 0

p_by_carrier_scotland = pd.concat([p_by_carrier_scotland, storage_by_carrier_scotland], axis=1)

# %%
network.lines_t.p0[['17', '18', '23', '24', '16']]
B6_to_scotland = network.lines_t.p0[['17', '18', '23', '24', '16']]

B6_import = B6_to_scotland.copy()
B6_export = B6_to_scotland.copy()

B6_import[B6_import > 0] = 0
B6_import = B6_import.sum(axis=1) * -1

B6_export[B6_export < 0] = 0
B6_export = B6_export.sum(axis=1) * -1
B6_export.name = 'B6 export'

# %%
# group biomass stuff
p_by_carrier_scotland['Biomass'] = (
    p_by_carrier_scotland['Biomass (dedicated)'])

# add B6 flows
p_by_carrier_scotland['B6 import'] = B6_import

# rename the hydro bit
p_by_carrier_scotland = p_by_carrier_scotland.rename(
    columns={'Large Hydro': 'Hydro'})
p_by_carrier_scotland = p_by_carrier_scotland.rename(
    columns={'Interconnector': 'Interconnectors Import'})

cols = ["Nuclear", 'Biomass',
        'Waste', "Oil", "Natural Gas",
        'Hydrogen', 'CCS Gas', 'CCS Biomass',
        "Pumped Storage Hydroelectric", 'Hydro',
        'Battery', 'Compressed Air', 'Liquid Air',
        "Wind Offshore", 'Wind Onshore', 'Solar Photovoltaics',
        'Unmet Load', 'B6 import'
        ]

p_by_carrier_scotland = p_by_carrier_scotland[cols]

p_by_carrier_scotland.drop(
    (p_by_carrier_scotland.max()[p_by_carrier_scotland.max() < 50.0]).index,
    axis=1, inplace=True)


colors = {"Coal": "grey",
          "Diesel/Gas oil": "black",
          "Diesel/gas Diesel/Gas oil": "black",
          'Oil': 'black',
          'Unmet Load': 'black',
          'Anaerobic Digestion': 'green',
          'Waste': 'chocolate',
          'Sewage Sludge Digestion': 'green',
          'Landfill Gas': 'green',
          'Biomass (dedicated)': 'green',
          'Biomass (co-firing)': 'green',
          'Biomass': 'green',
          'CCS Biomass': 'darkgreen',
          'Interconnectors Import': 'pink',
          'B6 import': 'pink',
          "Sour gas": "lightcoral",
          "Natural Gas": "lightcoral",
          'CCS Gas': "lightcoral",
          'Hydrogen': "deeppink",
          "Nuclear": "orange",
          'Shoreline Wave': 'aqua',
          'Tidal Barrage and Tidal Stream': 'aqua',
          'Hydro': "turquoise",
          "Large Hydro": "turquoise",
          "Small Hydro": "turquoise",
          "Pumped Storage Hydroelectric": "darkturquoise",
          'Battery': 'lime',
          'Compressed Air': 'greenyellow',
          'Liquid Air': 'lawngreen',
          "Wind Offshore": "lightskyblue",
          'Wind Onshore': 'deepskyblue',
          'Solar Photovoltaics': 'yellow'}

fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15,10)
(p_by_carrier_scotland / 1e3).plot(
    kind="area", ax=ax, linewidth=0,
    color=[colors[col] for col in p_by_carrier_scotland.columns])

# stacked area plot of negative values, prepend column names with '_' such that they don't appear in the legend
(B6_export / 1e3).plot.area(ax=ax, stacked=True, linewidth=0.)
# rescale the y axis
print(B6_export)
ax.set_ylim(B6_export.min() / 1e3, (p_by_carrier_scotland / 1e3).sum(axis=1).max())

# Shrink current axis's height by 10% on the bottom
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])
plt.axvline(x = '2045-12-07 20:00:00', color = 'black', label = 'Peak Scotland demand')
# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=True, ncol=3)
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
#           fancybox=True, shadow=True, ncol=5)
ax.set_ylabel("GW")

ax.set_xlabel("")
# Out:
# snapshot
# 2045-01-01 00:00:00   -7039.500219
# 2045-01-01 01:00:00   -7332.470853
# 2045-01-01 02:00:00   -6528.165314
# 2045-01-01 03:00:00   -7228.863618
# 2045-01-01 04:00:00   -5492.895508
#                           ...
# 2045-12-31 19:00:00   -5851.768171
# 2045-12-31 20:00:00   -5915.321428
# 2045-12-31 21:00:00   -6023.761642
# 2045-12-31 22:00:00   -5832.093161
# 2045-12-31 23:00:00   -5839.115554
# Name: B6 export, Length: 8760, dtype: float64
# c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\plotting\_matplotlib\core.py:1391: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(None, 0)
# Text(0.5, 0, '')

# %%
start = str(year) + '-12-07 00:00:00'
end = str(year) + '-12-08 23:30:00'
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15,10)
(p_by_carrier_scotland / 1e3)[start:end].plot(
    kind="area", ax=ax, linewidth=0,
    color=[colors[col] for col in p_by_carrier_scotland.columns])

# stacked area plot of negative values, prepend column names with '_' such that they don't appear in the legend
(B6_export / 1e3)[start:end].plot.area(ax=ax, stacked=True, linewidth=0.)
# rescale the y axis
print(B6_export)
ax.set_ylim(B6_export.min() / 1e3, 30)

# Shrink current axis's height by 10% on the bottom
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])
plt.axvline(x = '2045-12-07 20:00:00', color = 'black', label = 'Peak Scotland demand')
# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=True, ncol=3)
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
#           fancybox=True, shadow=True, ncol=5)
ax.set_ylabel("GW")

ax.set_xlabel("")
# Out:
# snapshot
# 2045-01-01 00:00:00   -7039.500219
# 2045-01-01 01:00:00   -7332.470853
# 2045-01-01 02:00:00   -6528.165314
# 2045-01-01 03:00:00   -7228.863618
# 2045-01-01 04:00:00   -5492.895508
#                           ...
# 2045-12-31 19:00:00   -5851.768171
# 2045-12-31 20:00:00   -5915.321428
# 2045-12-31 21:00:00   -6023.761642
# 2045-12-31 22:00:00   -5832.093161
# 2045-12-31 23:00:00   -5839.115554
# Name: B6 export, Length: 8760, dtype: float64
# c:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\plotting\_matplotlib\core.py:1391: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(None, 0)
# Text(0.5, 0, '')

# %% [markdown]
# ## Import and export analysis

# %%
df_import_export = pd.concat([B6_import, B6_export * -1], axis=1) / 1000000
df_import_export.columns = ['B6 Import', 'B6 Export']
df_import_export.to_csv('import_export_2045.csv')

df_import_export = df_import_export.groupby(df_import_export.index.to_period('M')).sum()
df_import_export.index = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df_import_export.plot(kind="bar", rot=0, figsize=(11.69, 8.27))
plt.ylabel('TWh')
plt.xlabel('2045')
plt.grid(color='grey', linewidth=1, axis='both', alpha=0.5)
