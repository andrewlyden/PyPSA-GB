# %% [markdown]
# # Comparison To Historical Data

# %% [markdown]
# PyPSA-GB can model the GB power system  by solving a network constrained Linear Optimal Power Flow (LOPF) problem. This notebook shows the example application of a historical 3 day period.

# %%
import os
from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv())
src_path = os.environ.get('PROJECT_SRC')
os.chdir(src_path)

# %%
import pypsa
import matplotlib.pyplot as plt
import pandas as pd
import cartopy.crs as ccrs

import data_reader_writer

# %% [markdown]
# ## Setting up simulation

# %% [markdown]
# Set the required inputs for the LOPF: the start, end and year of simulation, and the timestep.

# %%
# write csv files for import
start = '2018-01-01 00:00:00'
end = '2018-12-31 23:00:00'
# year of simulation
year = 2018
# time step as fraction of hour
time_step = 1

# %% [markdown]
# data_reader_writer is a script written to read in data from the various sources and write csv files in the format required for populating a PyPSA network object

# %%
data_reader_writer.data_writer(start, end, time_step, year, merge_generators=True)
# Out:
# C:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\core\indexing.py:1667: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = value

# %%
network = pypsa.Network()

network.import_from_csv_folder('LOPF_data')
# Out:
# WARNING:pypsa.io:
# Importing PyPSA from older version of PyPSA than current version.
# Please read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html
# carefully to prepare your network for import.
# Currently used PyPSA version [0, 19, 2], imported network file PyPSA version None.
#
# INFO:pypsa.components:Applying weightings to all columns of `snapshot_weightings`
# INFO:pypsa.io:Imported network LOPF_data has buses, generators, lines, loads, storage_units

# %% [markdown]
# To approximate n-1 security and allow room for reactive power flows, don't allow any line to be loaded above 70% of their thermal rating

# %%
contingency_factor = 0.7
network.lines.s_max_pu[0:99] *= contingency_factor

# %% [markdown]
# LOPF does not account for losses through lines. Here we add a 10% margin to the load in order to account for these losses.

# %%
network.loads_t.p_set.iloc[:, 0:29] *= 1.1

# %% [markdown]
# ## Running the optimisation

# %%
network.lopf(network.snapshots, solver_name="gurobi", pyomo=False)
# Out:
# INFO:pypsa.linopf:Prepare linear problem
# INFO:pypsa.linopf:Total preparation time: 122.86s
# INFO:pypsa.linopf:Solve linear problem using Gurobi solver
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-09-03
# Read LP format model from file C:\Users\alyden\AppData\Local\Temp\pypsa-problem-jstq_tfy.lp
# Reading time = 76.98 seconds
# obj: 27855382 rows, 7235761 columns, 49237120 nonzeros
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 27855382 rows, 7235761 columns and 49237120 nonzeros
# Model fingerprint: 0xf7092188
# Coefficient statistics:
#   Matrix range     [6e-05, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-06, 1e+04]
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Presolve removed 0 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 26795438 rows and 43801 columns (presolve time = 24s) ...
# Presolve removed 26795438 rows and 231476 columns (presolve time = 25s) ...
# Presolve removed 26795438 rows and 231476 columns (presolve time = 30s) ...
# Presolve removed 26795438 rows and 5106930 columns (presolve time = 35s) ...
# Presolve removed 26795438 rows and 5372573 columns (presolve time = 48s) ...
# Presolve removed 26802865 rows and 5380000 columns (presolve time = 50s) ...
# Presolve removed 27302865 rows and 5880000 columns (presolve time = 55s) ...
# Presolve removed 27308463 rows and 5885598 columns (presolve time = 70s) ...
# Presolve removed 27308463 rows and 5885598 columns (presolve time = 70s) ...
# Presolve removed 27308463 rows and 5903647 columns (presolve time = 76s) ...
# Presolve removed 27378535 rows and 5903647 columns
# Presolve time: 80.99s
# Presolved: 476847 rows, 1402186 columns, 2824930 nonzeros
#
# Ordering time: 0.39s
#
# Barrier statistics:
#  AA' NZ     : 1.781e+06
#  Factor NZ  : 1.029e+07 (roughly 800 MB of memory)
#  Factor Ops : 3.453e+08 (less than 1 second per iteration)
#  Threads    : 3
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.00373062e+11 -1.40106615e+12  3.85e+04 1.76e+01  2.31e+06    84s
#    1   5.06710932e+10 -4.63552194e+11  5.24e+03 2.27e-13  3.65e+05    84s
#    2   1.91080323e+10 -1.10216755e+11  9.81e+02 9.09e-13  7.04e+04    85s
#    3   1.15937390e+10 -9.91601444e+09  3.45e+01 3.87e-12  8.15e+03    86s
#    4   9.92187483e+09  2.97232177e+09  7.19e+00 1.17e-12  2.51e+03    87s
#    5   9.41152048e+09  6.30938183e+09  3.75e+00 4.69e-13  1.11e+03    88s
#    6   9.10663502e+09  7.32379529e+09  2.18e+00 2.49e-13  6.37e+02    88s
#    7   8.89812663e+09  7.97526834e+09  1.21e+00 1.71e-13  3.29e+02    89s
#    8   8.74185270e+09  8.31317887e+09  5.53e-01 1.71e-13  1.53e+02    90s
#    9   8.68159500e+09  8.43045825e+09  3.18e-01 1.14e-13  8.93e+01    91s
#   10   8.64511494e+09  8.51586383e+09  1.81e-01 1.14e-13  4.60e+01    92s
#   11   8.63150544e+09  8.53793219e+09  1.32e-01 1.14e-13  3.33e+01    92s
#   12   8.61738385e+09  8.56422521e+09  8.26e-02 1.71e-13  1.89e+01    93s
#   13   8.60880419e+09  8.57517505e+09  5.36e-02 1.14e-13  1.19e+01    94s
#   14   8.60224668e+09  8.58224472e+09  3.12e-02 7.18e-14  7.11e+00    95s
#   15   8.59890468e+09  8.58583231e+09  1.99e-02 6.90e-14  4.64e+00    96s
#   16   8.59798935e+09  8.58823896e+09  1.69e-02 8.04e-14  3.46e+00    96s
#   17   8.59691452e+09  8.58885797e+09  1.33e-02 9.55e-14  2.86e+00    97s
#   18   8.59627855e+09  8.58973437e+09  1.13e-02 7.94e-14  2.32e+00    98s
#   19   8.59523707e+09  8.59036662e+09  8.08e-03 7.11e-14  1.73e+00    98s
#   20   8.59501639e+09  8.59078833e+09  7.39e-03 9.92e-14  1.50e+00    99s
#   21   8.59437711e+09  8.59119262e+09  5.49e-03 9.17e-14  1.13e+00   101s
#   22   8.59391477e+09  8.59199513e+09  4.13e-03 7.25e-14  6.81e-01   102s
#   23   8.59350838e+09  8.59225198e+09  2.67e-03 6.86e-14  4.46e-01   104s
#   24   8.59317206e+09  8.59244783e+09  1.49e-03 7.72e-14  2.57e-01   105s
#   25   8.59305155e+09  8.59256849e+09  1.04e-03 7.43e-14  1.71e-01   106s
#   26   8.59296933e+09  8.59263409e+09  7.44e-04 6.59e-14  1.19e-01   107s
#   27   8.59287844e+09  8.59268413e+09  4.16e-04 8.17e-14  6.89e-02   107s
#   28   8.59282537e+09  8.59271180e+09  2.22e-04 6.71e-14  4.03e-02   108s
#   29   8.59279016e+09  8.59272797e+09  9.80e-05 8.72e-14  2.21e-02   109s
#   30   8.59278040e+09  8.59274520e+09  6.46e-05 8.07e-14  1.25e-02   109s
#   31   8.59276822e+09  8.59275150e+09  2.39e-05 7.44e-14  5.94e-03   110s
#   32   8.59276254e+09  8.59275809e+09  6.00e-06 9.84e-14  1.58e-03   110s
#   33   8.59276138e+09  8.59275978e+09  2.58e-06 2.34e-13  5.65e-04   111s
#   34   8.59276066e+09  8.59276039e+09  9.97e-07 1.22e-11  9.66e-05   112s
#   35   8.59276049e+09  8.59276044e+09  5.37e-06 9.99e-12  1.64e-05   113s
#   36   8.59276046e+09  8.59276045e+09  1.84e-07 1.41e-11  6.12e-07   113s
#   37   8.59276046e+09  8.59276046e+09  7.19e-10 1.12e-13  3.75e-11   114s
#
# Barrier solved model in 37 iterations and 113.88 seconds (45.61 work units)
# Optimal objective 8.59276046e+09
#
# Crossover log...
#
#   399882 variables added to crossover basis                      115s
#
#    58928 DPushes remaining with DInf 0.0000000e+00               117s
#        0 DPushes remaining with DInf 0.0000000e+00               119s
#
#   156593 PPushes remaining with PInf 0.0000000e+00               119s
#    86769 PPushes remaining with PInf 0.0000000e+00               121s
#    42879 PPushes remaining with PInf 0.0000000e+00               126s
#    26821 PPushes remaining with PInf 0.0000000e+00               133s
#    20244 PPushes remaining with PInf 0.0000000e+00               137s
#    14138 PPushes remaining with PInf 0.0000000e+00               142s
#     8919 PPushes remaining with PInf 0.0000000e+00               146s
#     5441 PPushes remaining with PInf 0.0000000e+00               151s
#     3029 PPushes remaining with PInf 0.0000000e+00               157s
#     2633 PPushes remaining with PInf 0.0000000e+00               160s
#        0 PPushes remaining with PInf 0.0000000e+00               164s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.2193220e-09    164s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   181486    8.5927605e+09   0.000000e+00   0.000000e+00    211s
#
# Solved with barrier
# Solved in 181486 iterations and 210.70 seconds (94.08 work units)
# Optimal objective  8.592760455e+09
# INFO:pypsa.linopf:Optimization successful. Objective value: 8.59e+09
# ('ok', 'optimal')

# %% [markdown]
# ## Power output by generation type

# %% [markdown]
# Group the generators by the carrier, and print their summed power outputs over the simulation period.

# %%
p_by_carrier = network.generators_t.p.groupby(
    network.generators.carrier, axis=1).sum()

storage_by_carrier = network.storage_units_t.p.groupby(
    network.storage_units.carrier, axis=1).sum()

# to show on graph set the negative storage values to zero
storage_by_carrier[storage_by_carrier < 0] = 0

p_by_carrier = pd.concat([p_by_carrier, storage_by_carrier], axis=1)

# interconnector exports
exports = network.loads_t.p
# multiply by negative one to convert it as a generator
# i.e. export is a positive load, but negative generator
exports['Interconnectors Export'] = exports.iloc[:, -6:].sum(axis=1) * -1
interconnector_export = exports[['Interconnectors Export']]

# group biomass stuff
p_by_carrier['Biomass'] = (
    p_by_carrier['Biomass (dedicated)'] + p_by_carrier['Biomass (co-firing)'] +
    p_by_carrier['Landfill Gas'] + p_by_carrier['Anaerobic Digestion'] +
    p_by_carrier['Sewage Sludge Digestion'])

# rename the hydro bit
p_by_carrier = p_by_carrier.rename(
    columns={'Large Hydro': 'Hydro'})
p_by_carrier = p_by_carrier.rename(
    columns={'Interconnector': 'Interconnectors Import'})

# %store p_by_carrier
p_by_carrier
# Out:
# Stored 'p_by_carrier' (DataFrame)
# carrier              Anaerobic Digestion  Biomass (co-firing)  \
# snapshot
# 2018-01-01 00:00:00           315.200000                 0.00
# 2018-01-01 01:00:00           315.200000                 0.00
# 2018-01-01 02:00:00           315.200000                 0.00
# 2018-01-01 03:00:00           315.200000                 0.00
# 2018-01-01 04:00:00           315.200000                 0.00
# ...                                  ...                  ...
# 2018-12-31 19:00:00           311.700000               509.54
# 2018-12-31 20:00:00           303.500000               509.54
# 2018-12-31 21:00:00           303.500000               509.54
# 2018-12-31 22:00:00           310.212381               509.54
# 2018-12-31 23:00:00           309.222371               509.54
#
# carrier              Biomass (dedicated)         Coal  EfW Incineration  \
# snapshot
# 2018-01-01 00:00:00               19.929   531.542604           396.576
# 2018-01-01 01:00:00                0.000     0.000000           396.576
# 2018-01-01 02:00:00                0.000     0.000000           396.576
# 2018-01-01 03:00:00                0.000     0.000000           396.576
# 2018-01-01 04:00:00                0.000     0.000000           396.576
# ...                                  ...          ...               ...
# 2018-12-31 19:00:00             2272.563  1961.000000           396.576
# 2018-12-31 20:00:00             2272.563  1961.000000           396.576
# 2018-12-31 21:00:00             2272.563  1961.000000           396.576
# 2018-12-31 22:00:00             2272.563  1961.000000           396.576
# 2018-12-31 23:00:00             2272.563  1961.000000           396.576
#
# carrier              Interconnectors Import  Landfill Gas       Hydro  \
# snapshot
# 2018-01-01 00:00:00             3163.499962         743.5  312.435669
# 2018-01-01 01:00:00             2756.500024         743.5  308.010233
# 2018-01-01 02:00:00             2771.499986         743.5  293.406300
# 2018-01-01 03:00:00             2626.499986         743.5  247.824325
# 2018-01-01 04:00:00             2625.499957         743.5  240.743629
# ...                                     ...           ...         ...
# 2018-12-31 19:00:00             3055.999925         734.8  228.226867
# 2018-12-31 20:00:00             2717.000034         708.7  166.189638
# 2018-12-31 21:00:00             2714.000037         708.7  163.239527
# 2018-12-31 22:00:00             2774.000030         722.8  159.502717
# 2018-12-31 23:00:00             1182.000015         730.8  168.353054
#
# carrier               Natural Gas      Nuclear  Oil  Sewage Sludge Digestion  \
# snapshot
# 2018-01-01 00:00:00   8408.289321  6833.530000  0.0                     50.2
# 2018-01-01 01:00:00   9747.058320  6833.530000  0.0                     50.2
# 2018-01-01 02:00:00   9981.267285  6833.530000  0.0                     50.2
# 2018-01-01 03:00:00   9154.443621  6833.530000  0.0                     50.2
# 2018-01-01 04:00:00   8229.633167  6833.530000  0.0                     50.2
# ...                           ...          ...  ...                      ...
# 2018-12-31 19:00:00  15472.300000  6270.701406  0.0                     50.2
# 2018-12-31 20:00:00  13223.028345  6238.481406  0.0                     50.2
# 2018-12-31 21:00:00   9875.306770  6206.261406  0.0                     50.2
# 2018-12-31 22:00:00   6799.600091  6174.041406  0.0                     50.2
# 2018-12-31 23:00:00   6885.170291  6141.821406  0.0                     50.2
#
# carrier              Shoreline Wave  Small Hydro  Solar Photovoltaics  \
# snapshot
# 2018-01-01 00:00:00            24.0    40.564332                  0.0
# 2018-01-01 01:00:00            24.0    39.989766                  0.0
# 2018-01-01 02:00:00            24.0    38.093700                  0.0
# 2018-01-01 03:00:00            24.0    32.175674                  0.0
# 2018-01-01 04:00:00            24.0    31.256368                  0.0
# ...                             ...          ...                  ...
# 2018-12-31 19:00:00            23.0    29.925967                  0.0
# 2018-12-31 20:00:00            23.0    22.203657                  0.0
# 2018-12-31 21:00:00            23.0    21.809509                  0.0
# 2018-12-31 22:00:00            23.0    20.791546                  0.0
# 2018-12-31 23:00:00            23.0    28.880077                  0.0
#
# carrier              Tidal Barrage and Tidal Stream  Wind Offshore  \
# snapshot
# 2018-01-01 00:00:00                             8.0    5322.763752
# 2018-01-01 01:00:00                             8.0    5318.656864
# 2018-01-01 02:00:00                             8.0    5315.245105
# 2018-01-01 03:00:00                             8.0    5312.001825
# 2018-01-01 04:00:00                             8.0    5306.942938
# ...                                             ...            ...
# 2018-12-31 19:00:00                             0.0    4056.750335
# 2018-12-31 20:00:00                             0.0    4415.811929
# 2018-12-31 21:00:00                             0.0    4823.838473
# 2018-12-31 22:00:00                             0.0    5143.001169
# 2018-12-31 23:00:00                             0.0    5137.163231
#
# carrier              Wind Onshore  Pumped Storage Hydroelectric      Biomass
# snapshot
# 2018-01-01 00:00:00   6499.869773                      0.000000  1128.829000
# 2018-01-01 01:00:00   6233.178739                      0.000000  1108.900000
# 2018-01-01 02:00:00   6067.016448                     93.065121  1108.900000
# 2018-01-01 03:00:00   5988.198334                      0.000000  1108.900000
# 2018-01-01 04:00:00   5794.067603                      0.000000  1108.900000
# ...                           ...                           ...          ...
# 2018-12-31 19:00:00   7759.746806                    699.569415  3878.803000
# 2018-12-31 20:00:00   7742.706223                      0.000000  3844.503000
# 2018-12-31 21:00:00   7626.915196                      0.000000  3844.503000
# 2018-12-31 22:00:00   7434.171470                      0.000000  3865.315381
# 2018-12-31 23:00:00   7314.210489                      0.000000  3872.325371
#
# [8760 rows x 20 columns]

# %% [markdown]
# Graph the power output of the different generation types...

# %%
cols = ["Nuclear", 'Shoreline Wave', 'Biomass',
        'EfW Incineration',
        "Coal", "Oil", "Natural Gas",
        "Pumped Storage Hydroelectric", 'Hydro',
        "Wind Offshore", 'Wind Onshore', 'Solar Photovoltaics',
        'Interconnectors Import'
        ]

p_by_carrier = p_by_carrier[cols]

p_by_carrier.drop(
    (p_by_carrier.max()[p_by_carrier.max() < 50.0]).index,
    axis=1, inplace=True)


colors = {"Coal": "grey",
          "Diesel/Gas oil": "black",
          "Diesel/gas Diesel/Gas oil": "black",
          'Oil': 'black',
          'Anaerobic Digestion': 'green',
          'EfW Incineration': 'chocolate',
          'Sewage Sludge Digestion': 'green',
          'Landfill Gas': 'green',
          'Biomass (dedicated)': 'green',
          'Biomass (co-firing)': 'green',
          'Biomass': 'green',
          'Interconnectors Import': 'pink',
          "Sour gas": "lightcoral",
          "Natural Gas": "lightcoral",
          "Nuclear": "orange",
          'Shoreline Wave': 'aqua',
          'Tidal Barrage and Tidal Stream': 'aqua',
          'Hydro': "turquoise",
          "Large Hydro": "turquoise",
          "Small Hydro": "turquoise",
          "Pumped Storage Hydroelectric": "darkturquoise",
          "Wind Offshore": "lightskyblue",
          'Wind Onshore': 'deepskyblue',
          'Solar Photovoltaics': 'yellow'}

fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15,10)
(p_by_carrier / 1e3).plot(
    kind="area", ax=ax, linewidth=0,
    color=[colors[col] for col in p_by_carrier.columns])

# stacked area plot of negative values, prepend column names with '_' such that they don't appear in the legend
(interconnector_export / 1e3).plot.area(ax=ax, stacked=True, linewidth=0.)
# rescale the y axis
ax.set_ylim([(interconnector_export / 1e3).sum(axis=1).min(), (p_by_carrier / 1e3).sum(axis=1).max()])

# Shrink current axis's height by 10% on the bottom
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])

# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
          fancybox=True, shadow=True, ncol=5)

ax.set_ylabel("GW")

ax.set_xlabel("")
# Out:
# C:\Users\alyden\Anaconda3\envs\PyPSA-GB\lib\site-packages\pandas\plotting\_matplotlib\core.py:1391: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(None, 0)
# Text(0.5, 0, '')

# %% [markdown]
# ## Simulated vs historical data power generation

# %% [markdown]
# We can group the generators by type and sum to calculate the total simulated power generation over the year in TWh.

# %%
# %store -r p_by_carrier

p_by_carrier = p_by_carrier.sum() / 1000000
# print(p_by_carrier)
p_by_carrier['Hydro'] = p_by_carrier['Small Hydro'] + p_by_carrier['Hydro']
p_by_carrier['Oil'] = 0.
p_by_carrier.drop(['Small Hydro', 'Anaerobic Digestion', 'Biomass (co-firing)', 'Biomass (dedicated)', 'Landfill Gas', 'Sewage Sludge Digestion', 'Shoreline Wave', 'Tidal Barrage and Tidal Stream'], inplace=True)
p_by_carrier
# Out:
# carrier
# Coal                              3.041580
# EfW Incineration                  3.474006
# Interconnectors Import           21.929185
# Hydro                             2.989967
# Natural Gas                     139.369596
# Nuclear                          59.480659
# Oil                               0.000000
# Solar Photovoltaics              14.709476
# Wind Offshore                    26.039266
# Wind Onshore                     29.113913
# Pumped Storage Hydroelectric      0.444903
# Biomass                          30.997940
# dtype: float64

# %% [markdown]
# Then the total of all simulated power generation is:

# %%
p_by_carrier.sum()
# Out:
# 331.59049179683797

# %% [markdown]
# BEIS publish reports on power generation, and here we extract the data for 2018 from X  and Y https://www.gov.uk/government/statistics/energy-trends-section-6-renewables

# %%
data = {'Coal': 16.0,
        'EfW Incineration': 3.5,
        'Interconnectors Import': 21.9,
        'Hydro': 5.4,
        'Natural Gas': 129.1,
        'Nuclear': 59.1,
        'Oil': 1.0,
        'Solar Photovoltaics': 12.7,
        'Wind Offshore': 26.5,
        'Wind Onshore': 30.4,
        'Pumped Storage Hydroelectric': 0.0,
        'Biomass': 31.5
        }
data_series = pd.Series(data)
data_series
# Out:
# Coal                             16.0
# EfW Incineration                  3.5
# Interconnectors Import           21.9
# Hydro                             5.4
# Natural Gas                     129.1
# Nuclear                          59.1
# Oil                               1.0
# Solar Photovoltaics              12.7
# Wind Offshore                    26.5
# Wind Onshore                     30.4
# Pumped Storage Hydroelectric      0.0
# Biomass                          31.5
# dtype: float64

# %%
data_series.sum()
# Out:
# 337.09999999999997

# %%
data_series.index
# Out:
# Index(['Coal', 'EfW Incineration', 'Interconnectors Import', 'Hydro',
#        'Natural Gas', 'Nuclear', 'Oil', 'Solar Photovoltaics', 'Wind Offshore',
#        'Wind Onshore', 'Pumped Storage Hydroelectric', 'Biomass'],
#       dtype='object')

# %%
# mylabels = data_series.index
# mycolors = categorical_cmap(3, 10)

colors = {"Coal": "grey",
          "Diesel/Gas oil": "black",
          "Diesel/gas Diesel/Gas oil": "black",
          'Oil': 'black',
          'Anaerobic Digestion': 'green',
          'EfW Incineration': 'chocolate',
          'Sewage Sludge Digestion': 'green',
          'Landfill Gas': 'green',
          'Biomass (dedicated)': 'green',
          'Biomass (co-firing)': 'green',
          'Biomass': 'green',
          'Interconnectors Import': 'pink',
          "Sour gas": "lightcoral",
          "Natural Gas": "lightcoral",
          "Nuclear": "orange",
          'Shoreline Wave': 'aqua',
          'Tidal Barrage and Tidal Stream': 'aqua',
          'Hydro': "turquoise",
          "Large Hydro": "turquoise",
          "Small Hydro": "turquoise",
          "Pumped Storage Hydroelectric": "darkturquoise",
          "Wind Offshore": "lightskyblue",
          'Wind Onshore': 'deepskyblue',
          'Solar Photovoltaics': 'yellow'}

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(20,15)

ax1.pie(data_series, labels=data_series.index,
        colors=[colors[col] for col in p_by_carrier.index], autopct="%1.1f%%",
        startangle=90, pctdistance=1.1, labeldistance=1.2)
ax1.set_title('Historical data')

simulated_generation = p_by_carrier
ax2.pie(simulated_generation, labels=simulated_generation.index,
        colors=[colors[col] for col in p_by_carrier.index], autopct="%1.1f%%",
        startangle=90, pctdistance=1.1, labeldistance=1.2)
ax2.set_title('Simulated data')

plt.tight_layout()

# %%
df = pd.DataFrame([simulated_generation, data_series], index=['Simulated', 'Historical']).T.round(1)
df.fillna(0, inplace=True)
df['Simulated - Historical'] = df['Simulated'] - df['Historical']
df['Simulated (%)'] = (df['Simulated'] / df['Simulated'].sum()* 100).round(1)
df['Historical (%)'] = (df['Historical'] / df['Historical'].sum()* 100).round(1)
df['Simulated (%) - Historical (%)'] = df['Simulated (%)'] - df['Historical (%)']
df.loc["Total"] = df.sum().round(2)
df
# Out:
#                               Simulated  Historical  Simulated - Historical  \
# Coal                                3.0        16.0                   -13.0
# EfW Incineration                    3.5         3.5                     0.0
# Interconnectors Import             21.9        21.9                     0.0
# Hydro                               3.0         5.4                    -2.4
# Natural Gas                       139.4       129.1                    10.3
# Nuclear                            59.5        59.1                     0.4
# Oil                                 0.0         1.0                    -1.0
# Solar Photovoltaics                14.7        12.7                     2.0
# Wind Offshore                      26.0        26.5                    -0.5
# Wind Onshore                       29.1        30.4                    -1.3
# Pumped Storage Hydroelectric        0.4         0.0                     0.4
# Biomass                            31.0        31.5                    -0.5
# Total                             331.5       337.1                    -5.6
#
#                               Simulated (%)  Historical (%)  \
# Coal                                    0.9             4.7
# EfW Incineration                        1.1             1.0
# Interconnectors Import                  6.6             6.5
# Hydro                                   0.9             1.6
# Natural Gas                            42.1            38.3
# Nuclear                                17.9            17.5
# Oil                                     0.0             0.3
# Solar Photovoltaics                     4.4             3.8
# Wind Offshore                           7.8             7.9
# Wind Onshore                            8.8             9.0
# Pumped Storage Hydroelectric            0.1             0.0
# Biomass                                 9.4             9.3
# Total                                 100.0            99.9
#
#                               Simulated (%) - Historical (%)
# Coal                                                    -3.8
# EfW Incineration                                         0.1
# Interconnectors Import                                   0.1
# Hydro                                                   -0.7
# Natural Gas                                              3.8
# Nuclear                                                  0.4
# Oil                                                     -0.3
# Solar Photovoltaics                                      0.6
# Wind Offshore                                           -0.1
# Wind Onshore                                            -0.2
# Pumped Storage Hydroelectric                             0.1
# Biomass                                                  0.1
# Total                                                    0.1

# %% [markdown]
# Looking at table above we can see
# - Gas too high
# - Coal too low
#
# Likely due to price dynamics of gas and coal which are not fully captured in marginal cost.
