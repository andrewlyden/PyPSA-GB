# %% [markdown]
# # Renewable Power and Storage

# %% [markdown]
# This notebook looks at data for the variable renewable power generators and storage units in the PyPSA-GB dataset. For historical years, 2010-2020, data on operational solar photovoltaics (PV), onshore wind, and offshore wind sites is sourced from the Renewable Energy Planning Database (REPD) https://www.gov.uk/government/publications/renewable-energy-planning-database-monthly-extract. Geocoordinates, technology type, and installed capacity are extracted and used for PyPSA generator components, as well as to generate power timeseries using Atlite.
#
# For modelling future energy scenarios, the FES2021 and FES2022 workbooks can be used to extract projected capacities. The spatial distribution of PV and onshore wind from 2020 is used as a baseline for future years and is scaled up based on projected capacities. For offshore wind in the near future (to 2030), the pipeline (from the REPD) and Sectoral Marine Plan (planning sites around Scotland) are used to update the spatial distribution from 2020 as it is anticipated that there will be a large expansion of offshore wind in the next 10 years which will significantly impact the current spatial distribution. From 2030 to 2050 it is assumed that the spatial distribution of offshore wind, along with PV and onshore wind, will be static.
#
# The only historical storage units for 2010-2020 included are large-scale pumped hydro stations. The future storage technologies represented are pumped hydro, batteries, liquid air storage and compressed air storage. The energy capacities and nominal power for the years 2021-2050 are extracted from the FES2021 or FES2022 workbook, and can be obtained for the four different scenarios. Storage technical parameters are sourced from https://www.sciencedirect.com/book/9780444626165/electrochemical-energy-storage-for-renewable-sources-and-grid-balancing.

# %% [markdown]
# ## Mapping historical renewable power sites

# %%
import os
from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv())
src_path = os.environ.get('PROJECT_SRC')
os.chdir(src_path)

# %%
import mapping
import renewables
import generators
import snapshots

import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
import pandas as pd
import cartopy.crs as ccrs
import cartopy.feature
from statistics import mean
import imageio

# %%
# tech = 'Advanced Conversion Technology'
# tech = 'Anaerobic Digestion'
# tech = 'Biomass (co-firing)'
# tech = 'Biomass (dedicated)'
# tech = 'EfW Incineration'
# tech = 'Fuel Cell (Hydrogen)'
# tech = 'Hot Dry Rocks (HDR)'
# tech = 'Landfill Gas'
# tech = 'Large Hydro'
# tech = 'Pumped Storage Hydroelectricity'
# tech = 'Sewage Sludge Digestion'
# tech = 'Shoreline Wave'
# tech = 'Small Hydro'
tech = 'Solar Photovoltaics'
# tech = 'Tidal Barrage and Tidal Stream'
# tech = 'Wind Offshore'
# tech = 'Wind Onshore'
# tech = 'Biomass (co-firing)'

# %%
color = 'deepskyblue'
marker_scaler = 2.
year = 2020

# %%
df = renewables.REPD_date_corrected(year)
df_res = df.loc[df['Technology Type'] == tech].reset_index(drop=True)

lon = df_res['lon'].values
lat = df_res['lat'].values

sizes = df_res['Installed Capacity (MWelec)'].values

plt.rcParams["figure.figsize"] = (15,10)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1,
                     projection=ccrs.PlateCarree())

extent = [-8.09782, 2.40511, 60, 49.5]
ax.set_extent(extent)
# ax.stock_img()
# ax.coastlines()
ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.scatter(lon, lat, s=sizes * marker_scaler, c=color, edgecolors='black')
ax.set_title(tech + ' - ' + str(year), fontsize=16)
l1 = ax.scatter([], [], s=min(sizes) * marker_scaler, edgecolors='black', color=color)
l2 = ax.scatter([], [], s=mean(sizes) * marker_scaler, edgecolors='black', color=color)
l3 = ax.scatter([], [], s=max(sizes) * marker_scaler, edgecolors='black', color=color)

label1 = round(min(sizes), 0)
label2 = round(mean(sizes), 0)
label3 = round(max(sizes), 0)
labels = [label1, label2, label3]
ax.legend([l1, l2, l3], labels, frameon=True, fontsize=12,
          loc=1, borderpad=1.5, labelspacing=1.5,
          title='Installed Capacity (MWelec)', scatterpoints=1)
# plt.savefig('../data/FES2021/' + str(year) + '_' + tech + '.png')
plt.show()

# %%
# do for all years
for y in range(2011, 2020 + 1):
    mapping.generator_map_plotter(tech, color, marker_scaler, y)

# %%
mapping.gif_maker(tech)

file = '../data/renewables/' + tech + '.gif'
from IPython.display import Image
Image(filename=file)

# %% [markdown]
# ## Historical renewable correction factors

# %% [markdown]
# Historical annual power output from different renewable power generators is reported by BEIS and this is compared to the power output calculated using Atlite.

# %%
df = renewables.RES_correction_factors()
df
# Out:
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:213: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[sites[name]].loc[df1.index[0]:date_operational] = 0.
#                    2010      2011      2012      2013      2014      2015  \
# Wind_Offshore  0.733633  0.775553  0.836134  0.742069  0.782873  0.770685
# Wind_Onshore   1.029483  0.976941  1.029872  0.938289  0.941133  0.936483
# PV                  NaN  4.831223  6.487221  2.799122  1.964904  1.527666
#
#                    2016      2017      2018      2019      2020
# Wind_Offshore  0.732413  0.792680  0.820076  0.871102  0.878444
# Wind_Onshore   0.926565  0.956799  0.941639  0.969856  0.908810
# PV             1.407315  1.438742  1.461258  1.437970  1.461977

# %% [markdown]
# Both wind onshore and offshore power production are overestimated, and this is likely due to a combination of limitations with use of reanalysis datasets, neglecting of wake effects, and maintenance/down town. However, there is an underestimation of PV power production and this is because <150kW installations are not included in the REPD, which means that domestic scale systems are not included. By presuming the spatial distribution of <150kW systems is the same as >150kW systems we can scale the power capacities of the PV generators to match historical data.

# %%
df.loc['PV', 2010] = 0
plt.figure(figsize=(12, 6))
plt.plot(df.loc['Wind_Offshore'])
plt.plot(df.loc['Wind_Onshore'])
plt.plot(df.loc['PV'])
plt.legend(df.index)

# %% [markdown]
# ## Closer look at renewable power generation timeseries

# %% [markdown]
# Choose a year to analyse, and if future year then choose a baseline year in the following cell.

# %%
year = 2050

# %%
start = str(year) + '-01-01 00:00:00'
end = str(year) + '-12-31 23:30:00'

# time step as fraction of hour
time_step = 0.5
freq = snapshots.write_snapshots(start, end, time_step)

# write generators contains the applying correction factors function
generators.write_generators(time_step, year)

if year > 2020:
    # if future choose a baseline year
    year_baseline = 2019
    scenario = 'Leading The Way'
    generators.future_p_nom(year, time_step, scenario, FES=2022)
    generators.write_generators_p_max_pu(start, end, freq, year, 2022, year_baseline=year_baseline, scenario=scenario)
    generators.unmet_load()

elif year <= 2020:
    generators.write_generators_p_max_pu(start, end, freq, year, 2022)

df_RES = pd.read_csv('LOPF_data/generators-p_max_pu.csv', index_col=0)
df_RES
# Out:
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\snapshots.py:31: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   dti = pd.date_range(
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\generators.py:655: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ True  True  True ...  True  True  True]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'committable'] = df['committable'].astype('bool')
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\generators.py:674: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[50160.         76000.             0.         ...    98.79999638
#  24510.           646.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'start_up_cost'] *= df['p_nom']
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\generators.py:655: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ True  True  True ...  True  True  True]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'committable'] = df['committable'].astype('bool')
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\generators.py:674: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[50160.         76000.             0.         ...    98.79999638
#  24510.           646.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'start_up_cost'] *= df['p_nom']
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\generators.py:721: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   generators['p_nom']['West Burton'] = 0
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\generators.py:795: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df.index = pd.to_datetime(df.index, infer_datetime_format=True)
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\distance_calculator.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_point = {'lon': df['x'][i], 'lat': df['y'][i]}
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\distance_calculator.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_point = {'lon': df['x'][i], 'lat': df['y'][i]}
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\generators.py:654: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1 0 0 ... 1 1 1]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'committable'] = np.select(conditions, committable_)
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\generators.py:655: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ True False False ...  True  True  True]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'committable'] = df['committable'].astype('bool')
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\generators.py:655: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ True False False ...  True  True  True]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'committable'] = df['committable'].astype('bool')
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\generators.py:674: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[    0.             0.             0.         ... 34011.14111328
#  28069.83972168 30939.60046387]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'start_up_cost'] *= df['p_nom']
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:459: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_tidal_lagoon_capacities = df_tidal_lagoon_capacities.fillna(0)
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\distance_calculator.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_point = {'lon': df['x'][i], 'lat': df['y'][i]}
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:513: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_tidal_stream_capacities = df_tidal_stream_capacities.fillna(0)
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\distance_calculator.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_point = {'lon': df['x'][i], 'lat': df['y'][i]}
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:567: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_wave_power_capacities = df_wave_power_capacities.fillna(0)
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\distance_calculator.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data_point = {'lon': df['x'][i], 'lat': df['y'][i]}
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:1333: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex.
#   result.index = result.index + pd.DateOffset(year=year)
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:1334: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex.
#   result_norm.index = result_norm.index + pd.DateOffset(year=year)
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\generators.py:1473: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df_offshore = df_offshore.resample(freq).interpolate('polynomial', order=2)
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\generators.py:1508: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df_onshore = df_onshore.resample(freq).interpolate('polynomial', order=2)
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\generators.py:1556: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df_PV = df_PV.resample(freq).interpolate('polynomial', order=1)
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:293: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   dti = pd.date_range(start='2015-02-22 00:00:00', end='2020-12-31 23:30:00', freq='0.5H')
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# ...
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro.loc[:, name] = (df2.loc[name, 'normalised'] * total_time_series).copy()
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\renewables.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_hydro_norm.loc[:, name] = (
# C:\Users\alyden\OneDrive - University of Edinburgh\Python\PyPSA-GB-fix\PyPSA-GB\PyPSA-GB\generators.py:1605: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df_hydro = df_hydro.resample(freq).mean()
#                      Hywind Scotland Pilot Park (Hywind 2) Demonstrator  \
# name
# 2050-01-01 00:00:00                                           1.000000
# 2050-01-01 00:30:00                                           1.000000
# 2050-01-01 01:00:00                                           1.000000
# 2050-01-01 01:30:00                                           1.000000
# 2050-01-01 02:00:00                                           1.000000
# ...                                                                ...
# 2050-12-31 21:30:00                                           0.959733
# 2050-12-31 22:00:00                                           0.966778
# 2050-12-31 22:30:00                                           0.962127
# 2050-12-31 23:00:00                                           0.945779
# 2050-12-31 23:30:00                                           0.945779
#
#                      Beatrice Demonstrator  Burbo Bank  \
# name
# 2050-01-01 00:00:00               1.000000    0.998449
# 2050-01-01 00:30:00               1.000000    0.998630
# 2050-01-01 01:00:00               1.000000    0.998549
# 2050-01-01 01:30:00               1.000000    0.998207
# 2050-01-01 02:00:00               1.000000    0.997720
# ...                                    ...         ...
# 2050-12-31 21:30:00               0.286398    0.224614
# 2050-12-31 22:00:00               0.272982    0.182529
# 2050-12-31 22:30:00               0.289324    0.183538
# 2050-12-31 23:00:00               0.335424    0.227640
# 2050-12-31 23:30:00               0.335424    0.227640
#
#                      Gunfleet Sands - (Demo) Extension  Gunfleet Sands II  \
# name
# 2050-01-01 00:00:00                           0.355643           0.450097
# 2050-01-01 00:30:00                           0.356263           0.449326
# 2050-01-01 01:00:00                           0.363484           0.457552
# 2050-01-01 01:30:00                           0.377306           0.474776
# 2050-01-01 02:00:00                           0.404703           0.510393
# ...                                                ...                ...
# 2050-12-31 21:30:00                           0.522030           0.647349
# 2050-12-31 22:00:00                           0.436542           0.551402
# 2050-12-31 22:30:00                           0.407859           0.519177
# 2050-12-31 23:00:00                           0.435981           0.550676
# 2050-12-31 23:30:00                           0.435981           0.550676
#
#                      Gunfleet Sands Offshore Wind Scheme  Inner Dowsing  \
# name
# 2050-01-01 00:00:00                             0.450097       0.993255
# 2050-01-01 00:30:00                             0.449326       0.994529
# 2050-01-01 01:00:00                             0.457552       0.995643
# 2050-01-01 01:30:00                             0.474776       0.996597
# 2050-01-01 02:00:00                             0.510393       0.997287
# ...                                                  ...            ...
# 2050-12-31 21:30:00                             0.647349       0.315004
# 2050-12-31 22:00:00                             0.551402       0.285380
# 2050-12-31 22:30:00                             0.519177       0.290130
# 2050-12-31 23:00:00                             0.550676       0.329255
# 2050-12-31 23:30:00                             0.550676       0.329255
#
#                      Kentish Flats      Lynn  North Hoyle  ...  \
# name                                                       ...
# 2050-01-01 00:00:00       0.331019  0.993255     0.998194  ...
# 2050-01-01 00:30:00       0.323019  0.994529     0.998592  ...
# 2050-01-01 01:00:00       0.323650  0.995643     0.998615  ...
# 2050-01-01 01:30:00       0.332910  0.996597     0.998264  ...
# 2050-01-01 02:00:00       0.359857  0.997287     0.997749  ...
# ...                            ...       ...          ...  ...
# 2050-12-31 21:30:00       0.546296  0.315004     0.175264  ...
# 2050-12-31 22:00:00       0.426086  0.285380     0.139727  ...
# 2050-12-31 22:30:00       0.371481  0.290130     0.138307  ...
# 2050-12-31 23:00:00       0.382480  0.329255     0.171004  ...
# 2050-12-31 23:30:00       0.382480  0.329255     0.171004  ...
#
#                      Abhainn Gleann Nam Fiadh  Allt Cheanna Mhuir Hydro  \
# name
# 2050-01-01 00:00:00                  0.215862                  0.215862
# 2050-01-01 00:30:00                  0.206801                  0.206801
# 2050-01-01 01:00:00                  0.198273                  0.198273
# 2050-01-01 01:30:00                  0.196141                  0.196141
# 2050-01-01 02:00:00                  0.189212                  0.189212
# ...                                       ...                       ...
# 2050-12-31 21:30:00                  0.353907                  0.353907
# 2050-12-31 22:00:00                  0.345912                  0.345912
# 2050-12-31 22:30:00                  0.345379                  0.345379
# 2050-12-31 23:00:00                  0.335785                  0.335785
# 2050-12-31 23:30:00                  0.370963                  0.370963
#
#                      Keltneyburn Hydro  Ceannacroc.1  \
# name
# 2050-01-01 00:00:00           0.215862      0.215862
# 2050-01-01 00:30:00           0.206801      0.206801
# 2050-01-01 01:00:00           0.198273      0.198273
# 2050-01-01 01:30:00           0.196141      0.196141
# 2050-01-01 02:00:00           0.189212      0.189212
# ...                                ...           ...
# 2050-12-31 21:30:00           0.353907      0.353907
# 2050-12-31 22:00:00           0.345912      0.345912
# 2050-12-31 22:30:00           0.345379      0.345379
# 2050-12-31 23:00:00           0.335785      0.335785
# 2050-12-31 23:30:00           0.370963      0.370963
#
#                      Bruach Caorainn Hydro Scheme  Llyn Celyn  Caban Coch  \
# name
# 2050-01-01 00:00:00                      0.215862    0.215862    0.215862
# 2050-01-01 00:30:00                      0.206801    0.206801    0.206801
# 2050-01-01 01:00:00                      0.198273    0.198273    0.198273
# 2050-01-01 01:30:00                      0.196141    0.196141    0.196141
# 2050-01-01 02:00:00                      0.189212    0.189212    0.189212
# ...                                           ...         ...         ...
# 2050-12-31 21:30:00                      0.353907    0.353907    0.353907
# 2050-12-31 22:00:00                      0.345912    0.345912    0.345912
# 2050-12-31 22:30:00                      0.345379    0.345379    0.345379
# 2050-12-31 23:00:00                      0.335785    0.335785    0.335785
# 2050-12-31 23:30:00                      0.370963    0.370963    0.370963
#
#                      River Coiltie Hydro Scheme  Eas a Ghaill  \
# name
# 2050-01-01 00:00:00                    0.215862      0.215862
# 2050-01-01 00:30:00                    0.206801      0.206801
# 2050-01-01 01:00:00                    0.198273      0.198273
# 2050-01-01 01:30:00                    0.196141      0.196141
# 2050-01-01 02:00:00                    0.189212      0.189212
# ...                                         ...           ...
# 2050-12-31 21:30:00                    0.353907      0.353907
# 2050-12-31 22:00:00                    0.345912      0.345912
# 2050-12-31 22:30:00                    0.345379      0.345379
# 2050-12-31 23:00:00                    0.335785      0.335785
# 2050-12-31 23:30:00                    0.370963      0.370963
#
#                      River Pattack (resubmission)
# name
# 2050-01-01 00:00:00                      0.215862
# 2050-01-01 00:30:00                      0.206801
# 2050-01-01 01:00:00                      0.198273
# 2050-01-01 01:30:00                      0.196141
# 2050-01-01 02:00:00                      0.189212
# ...                                           ...
# 2050-12-31 21:30:00                      0.353907
# 2050-12-31 22:00:00                      0.345912
# 2050-12-31 22:30:00                      0.345379
# 2050-12-31 23:00:00                      0.335785
# 2050-12-31 23:30:00                      0.370963
#
# [17520 rows x 2080 columns]

# %% [markdown]
# Pick one renewable generator to plot the timeseries of.

# %%
df_RES.columns.values.tolist()
# Out:
# ['Hywind Scotland Pilot Park (Hywind 2) Demonstrator',
#  'Beatrice Demonstrator',
#  'Burbo Bank',
#  'Gunfleet Sands - (Demo) Extension',
#  'Gunfleet Sands II',
#  'Gunfleet Sands Offshore Wind Scheme',
#  'Inner Dowsing',
#  'Kentish Flats',
#  'Lynn',
#  'North Hoyle',
#  'Rhyl Flats',
#  'Robin Rigg East',
#  'Robin Rigg West',
#  'Scroby Sands',
#  'Thanet',
#  'Walney 1',
#  'Kentish Flats 2',
#  'European Offshore Wind Deployment Centre (EOWDC) (Aberdeen Bay - Demonstration site)',
#  'Walney 2',
#  'Ormonde Offshore',
#  'Greater Gabbard Wind Farm',
#  'London Array Phase 1',
#  'Sheringham Shoal',
#  'Centrica (Lincs)',
#  'Teeside Offshore Wind Farm',
#  'Race Bank (Phase 1)',
#  'West of Duddon Sands',
#  'Rampion Offshore Wind Farm (Hastings Zone)',
#  'Beatrice',
#  'Blyth Offshore Wind Test Site',
#  'East Anglia 1 (EA 1)',
#  'Hornsea 1 - Heron & Njord',
#  'Galloper Wind Farm',
#  'Levenmouth demonstration turbine (Fife Energy Park)',
#  'Walney 3',
#  'Dudgeon East',
#  'Burbo Bank Extension (Burbo Bank 2)',
#  'Gwynt y Mor',
#  'Humber Gateway A',
#  'Westermost Rough A',
#  'Barrow',
#  'Race Bank (Phase 2)',
#  'East Anglia 3 (EA 3)',
#  'Hornsea 3',
#  'The East Anglia Array - Norfolk Vanguard',
#  'Hornsea 2 - Optimus and Breesea',
#  'Dogger Bank C (was Teesside A)',
#  'Inch Cape',
#  'Triton Knoll',
#  'MacColl Offshore Windfarm (Moray East)',
#  'Telford Offshore Windfarm (Moray East)',
#  'Stevenson Offshore Windfarm (Moray East)',
#  'Seagreen Phase 1 (Alpha)',
#  'Dogger Bank A & B (was Creyke Beck A & B)',
#  'Forth of Firth (Methil)',
#  'Kincardine Offshore Windfarm',
#  'Moray Firth 2 (West)',
#  'Dounreay Tri Floating Wind Demonstration',
#  'Neart na Gaoithe (Resubmission)',
#  'The East Anglia Array - Norfolk Boreas',
#  'Sofia (Teesside B)',
#  'N1',
#  'N2',
#  'N3',
#  'N4',
#  'NE1',
#  'NE2',
#  'NE3',
#  'NE4',
#  'NE6',
#  'NE7',
#  'NE8',
#  'E1',
#  'E2',
#  'E3',
#  'W1',
#  'South Beach Wind Turbine (Somerton)',
#  'Swaffham 1 - Ecotech Wind Park',
#  'Mynydd Gorddu Wind Farm',
#  'Cefn Croes Wind Farm',
#  "Carno 'B' Wind Farm",
#  "Carno 'A' Wind Farm",
#  "Cemmaes 'B' Wind Farm",
#  'Trysglwyn Wind Farm',
#  "Hafoty Ucha '2' and '3' Wind Turbine",
#  'Royal Seaforth Dock Wind Farm',
#  "Cemmaes 'C' Wind Farm",
#  'Llanbabo Wind Farm',
#  'Tow Law Wind Farm',
#  'Kirkheaton Wind Farm',
#  'Great Eppleton Wind Farm',
#  'Great Orton Wind Farm (Extension)',
#  'Harlock Hill Wind Farm',
#  'Wharrels Hill Wind Farm',
#  'Siddick Wind Farm',
#  'Oldside Wind Farm',
#  'Haverigg Extension Wind Farm',
#  'Blaen Bowi Wind Farm',
#  'Parc-Cynog Wind Farm',
#  'Moel Maelogen A',
#  'Out Newton Wind Farm',
#  'Brockholes Wind Cluster',
#  'Kilbraur Windfarm Farlary - Extension',
#  'Maesgwyn',
#  'Spicer Hill Wind Farm',
#  'Ford Motor Company Ltd (Extension)',
#  'FMC Technologies',
#  'Boyndie Airfield Extension',
#  'Blue Gates Farm',
#  'Celcon Blocks Ltd',
#  "Hammar's Hill",
#  'F M C Land, Pitreavie Business Park',
#  'Strath of Brydock - Extension',
#  'Hare Hill (East Ayrshire)',
#  'Kirkby Moor',
#  'Bambers II',
#  'Millennium Extension II',
#  'Cairnmore Farm',
#  'St Fergus Moss Wind Farm',
#  'West Hill, Flotta',
#  'Chelker Reservoir (Retention of Turbines)',
#  'Whitelee Windfarm Extension phase 2',
#  'Hill of Balquhindachy extension',
#  'Taff Ely Wind Farm',
#  'Mossmorran Wind Farm',
#  'Courtstone Wind Turbine',
#  'Lairg Wind Farm',
#  'G24 Innovations Turbine',
#  'Mornflake Oats Wind Turbine',
#  'Clochnahill Wind Farm',
#  'St John Hill',
#  'MARCH SEWAGE TREATMENT WORKS - WIND TURBINE',
#  'Burnfoot Hill',
#  'Chelker Reservoir',
#  'Strath of Brydock',
#  "House O'Hill",
#  'Bagmoor',
#  'Croda Chemicals Europe',
#  'Eastman Chemicals, Workington',
#  'Lindhurst Wind Farm',
#  'Craigengelt',
#  'Saltend Wind Turbine',
#  'Loftsome Bridge',
#  'Nissan Wind Farm',
#  'Parc Cynog Extension',
#  'Ranson Moor (phase 1)',
#  'Ranson Moor Wind Farm (Phase 2)',
#  'West Durham Wind Farm',
#  'Dyffryn Brodyn Wind Farm',
#  'North Red Bog',
#  'Milton Keynes Wind Farm',
#  'Broom Hill Farm',
#  'Winscales Moor',
#  'Wind Farm Africa Alive',
#  'Beinn Tharsuinn Extension (Beinn nan Oighrean)',
#  "St John's Well",
#  'Hellrigg Wind farm - Resubmission',
#  'Bryn titli Windfarm',
#  'Delabole (Repowering)',
#  'Whittlesey',
#  'Advanced Manufacturing Research Centre',
#  'Solutia UK Ltd',
#  'High Haswell Wind Farm',
#  'Llandinam Windfarm',
#  'Goonhilly Downs Wind Farm Repower',
#  'MSD Cramlington',
#  'Skelmonae Wind Farm',
#  'Carn Vean',
#  'Dewlay Cheese Wind Turbine',
#  'Coal Clough Wind Farm',
#  'Myres Hill',
#  'High Sharpley Wind Farm',
#  'National Wind Turbine Test Site',
#  'Little Cheyne Court Wind Farm',
#  'Long Hill Road',
#  'Ness point Wind Turbine 1',
#  'Causeymire',
#  'Hadyard Hill',
#  'Hare Hill (B)',
#  'Crystal Rig Phase 1',
#  'Black Law',
#  'Ardrossan',
#  "Braes O'Doune",
#  'Thorfinn Wind Farm - NM1500',
#  'Boulfruich',
#  'Bicker Fen',
#  'Stags Holt',
#  'Glass Moor',
#  'Gedney Marsh',
#  'Ben Aketil',
#  'Knabs Ridge Windfarm',
#  'Kelburn',
#  'Ramsey 1',
#  'Bambers Farm',
#  'Ford Wind Park - Dagenham',
#  'Swaffham Plashes II',
#  'Shooters Bottom Wind Park',
#  'Caton Moor Windfarm Repowering',
#  'Moel Maelogen A Phase 2',
#  'Scout Moor Windfarm',
#  'The Haven',
#  'The Hollies',
#  'Tullo Farm',
#  'Avonmouth Port',
#  'Dummuie',
#  'Earlsburn',
#  'Kilbraur Windfarm',
#  'Achany Wind Farm',
#  'Bilbster Wind Farm',
#  'Green Park',
#  'Carcant Windfarm',
#  'Butterwick Moor',
#  'Hagshaw Hill Wind Farm Extension',
#  'Southern Law',
#  'Llangwyryfon',
#  'Pates Hill',
#  'Roskrow Wind Turbines',
#  'Greendykeside',
#  'Loscar Farm',
#  'Langley Moor',
#  'Arecleoch Windfarm',
#  'Mark Hill',
#  'Westmill Wind Farm',
#  'Lodge Farm 1',
#  "Carno 'A'and 'B' Wind Farm, (Extension)",
#  'Achairn',
#  'High Hedley Hope 2 (Extension)',
#  'Beinn an Tuirc',
#  'Cnoc Donn Arnicle',
#  'Beinn Ghlas Wind Farm',
#  'Bendealt Wind Farm, Highland',
#  'Meall an Tuirc Wind Farm',
#  'An Suidhe',
#  'Roughside Hill',
#  'Bowbeat Wind Farm',
#  'Hagshaw Hill Wind Farm',
#  'Arnish Moor',
#  'Burgar Hill',
#  'Thorfinn Wind Farm - NM2000',
#  'Hill of Lybster',
#  'Burradale Hill',
#  'Glens of Foudland',
#  'Castle Pill - Repowering',
#  'New Holland',
#  'Weston Airfield Wind Turbines',
#  'Orton Park Farm',
#  'PROMISED LAND FARM',
#  'Nethercott Farm',
#  'Bonerbo Wind Turbines (resubmission)',
#  'Princes Gate Spring Water',
#  'Phase 1 Bettyhill Wind Farm',
#  'Sibelco Brassington',
#  'Lambrigg Wind Farm',
#  'Askam',
#  'Bears Down Wind Farm',
#  'Welton Of Creuchies',
#  'Droop Hill Wind Farm x',
#  'Denhill',
#  'Haddo',
#  'Gairnieston Farm',
#  'Burgar Hill (land Near), Evie',
#  'Tod Hill Farm Wind Turbines',
#  'Moorhouse Farm',
#  'Royd Moor',
#  'Stroupster Wind Farm - additional turbine',
#  'Little Belhus Restoration Site',
#  'Crystal Rig Wind Farm Phase 2a',
#  'Clachan Flats Wind Farm',
#  'Fen Farm',
#  'Darracott Moor',
#  'Lochhead Farm',
#  'Toddleburn',
#  'Crimp Wind Farm - resubmission',
#  'Hedley Hope',
#  'Tangy Wind Farm/Tangy 1',
#  'Coldham Hall',
#  'Whitemill Wind Farm',
#  'Green Knowes',
#  'Whitelee',
#  'Great Orton',
#  'Winscales Phase I and II',
#  'Holmside Hall',
#  'High Volts Wind Farm',
#  'Hare Hill',
#  'Great Eppleton Farm Repowering',
#  'Haswell Moor',
#  'Worksop - B&Q',
#  'Cold Northcott',
#  'Upper Ardgrain Wind Farm',
#  'Rothiesholm',
#  'Hill of Easterton',
#  'Port of Liverpool - wind',
#  'Rothes Wind (Cairn Uish)',
#  'Crystal Rig Extension II',
#  'Glenkerie Wind Farm',
#  'Lissett Airfield Wind Farm',
#  'Methlick Farmers Wind Energy Project',
#  'Rheidol Wind Farm',
#  'Deucheran Hill',
#  'Bryn Du',
#  'Dun Law',
#  'Black Hill (Borders)',
#  'Four Burrows Wind Farm',
#  'Dun Law Extension',
#  'Lochelbank Wind Farm II',
#  'Cruach Mhor',
#  'Wern Ddu Wind Farm',
#  'Hagshaw Hill (S15) Wind Farm, Lanarkshire',
#  'Muirake',
#  'Millennium Extension',
#  'Rusholme Wind Farm',
#  'Longpark',
#  'Walkway',
#  'Coldham',
#  'Red Tile',
#  'Deeping St Nicholas Wind Farm',
#  'Lowca Wind Farm',
#  'Fairfield Farm',
#  'Haverigg Repowering (Haverigg II)',
#  'Beinneun Windfarm Extension',
#  'Ewe Hill (extension)',
#  'Moy Wind Farm (2nd Application)',
#  'Rosehill Wind Turbines',
#  'Twin Rivers',
#  'Blyth Harbour Wind Farm',
#  'Penrhys Wind Farm/Ferndale Power Factory',
#  'Gordonbush',
#  'Avonmouth Wind Power',
#  'Gordonstown Hill Wind Farm',
#  'The Rosti Factory',
#  'Ben Aketil Extension',
#  'Lochcarnan Community Windfarm',
#  'The Grange Wind Farm',
#  'Humphrey Group',
#  'Rodbaston',
#  'Boundary Lane',
#  'Nutberry Wind Farm',
#  'Penny Hill Lane',
#  'West Knock Wind Cluster',
#  'Low Spinney Wind Farm',
#  'Westfield',
#  'Swinford Wind Farm',
#  'Burnt House Farm',
#  'Calder Water Community Wind Farm',
#  'Millour Hill Community Windfarm (Re-submission)',
#  'Netherton of Windyhills',
#  'Gallowhill',
#  'Frodsham Marsh',
#  'Brechfa Forest West',
#  'Greenhill Croft',
#  'Severn Trent STW',
#  'Spaldington Airfield',
#  'Hillhead of Auquhirie, Resubmission',
#  'Middleton Wind Farm',
#  'Orchard End (Resubmission)',
#  'Mynydd Bwllfa Wind Farm - Resubmission',
#  'Tirgwynt',
#  'Garreg Lwyd',
#  'Castle of Auchry Farm',
#  'Little Byth',
#  'Yonderton Farm',
#  'Oakdale Business Park',
#  'Boddington Reservoir',
#  'HMP Standford Hill',
#  'Sharpness Docks',
#  'Sancton Hill - Resubmission',
#  'Port of Sheerness Wind Farm (was Lappel Bank)',
#  'Stonish Hill Re-submission (Bilsthorpe)',
#  'Stags Holt Extension',
#  'North Yell Wind Farm (Garth Community Wind Farm)',
#  'Glenurquhart and Strathglass Wind Farm project',
#  'Damhead Farm',
#  'Hyndburn Wind Farm',
#  'Tedder Hill Wind cluster',
#  'Lynemouth Windfarm (Resubmission)',
#  'Wingates Wind Farm',
#  'Wathegar wind farm',
#  'Allt Dearg Wind Farmers LLP',
#  'Hameldon Hill extension',
#  'Dalby',
#  'Glass moor Extension',
#  'Cour Wind Farm',
#  'Upper Wheedlemont Farm',
#  'Shielburn Farm',
#  'Beinneun',
#  'Seamer Wind Farm - Hambleton',
#  'Fanny House Farm/Heysham Moss',
#  'Newthorpe Wind Turbine',
#  'Chelveston Renewable Energy Park Wind Farm (Bedford)',
#  'Torrance Farm',
#  'Land at Overside and Greenwellheads Farms',
#  'Lancaster University (wind)',
#  'Myreton Crossroads',
#  'Auchinderran Wind Farm',
#  'The Limes Wind Turbines',
#  'Milton of Fisherie Wind Cluster',
#  'Blantyre Muir Wind Farm',
#  'Lilbourne Wind Farm',
#  'Tullo Wind Farm North Extension (Shiels Wind Farm)',
#  'Easter Melrose Wind Energy Project',
#  'Newton Marsh Wind Project',
#  'North Pickenham Airfield',
#  'Wythegill Wind Turbine',
#  'Roos Wind Farm (Resubmission)',
#  'Yonderton Wind Cluster',
#  'Spurness Wind Farm Repowering',
#  'St Johns Wells Wind Cluster Extension',
#  'GlaxoSmithKline Wind Project',
#  'K L Technologies Wind Turbine',
#  'Skeddoway Farm Wind Turbine',
#  'Coire Na Cloiche Wind Farm',
#  'Ardoch and Over Enoch Wind Farm (Over Enoch)',
#  'Ystgellog Farm Wind Farm',
#  'NEILSTON WIND FARM',
#  'Greencroft Estate Turbines',
#  'Crossness Sewage Works Turbine',
#  'Muirhall Extension',
#  'Freasdail Wind Farm',
#  'Nash Waste Water Treatment Works Turbine',
#  'Marston Vale Country Park Wind Turbine',
#  'Energy Works Hull - Wind Turbine',
#  'Mynydd Y Gwrhyd Windfarm (resubmission)',
#  'Severn Trent Water - Stoke Bardolph Wind Turbine',
#  'Barns of Ayre Wind Turbines (2)',
#  'Newton Down',
#  'North Steads Wind Farm',
#  'Hill of Tillymorgan (Kirkton Farm) Wind turbines (resubmission)',
#  'LADEHEAD FARM - WIND TURBINES',
#  'Garlenick Estate 2 - Wind Turbines',
#  'Goonabarn Farm Wind Turbines',
#  'Bloodhills - repowering',
#  'Ardoch and Over Enoch Wind Farm (Ardoch)',
#  'Avonmouth Port II',
#  'Tween Bridge Windfarm',
#  'Mynydd Portref',
#  'Fforch Nest Wind Farm pt2',
#  'Wadlow Wind Farm',
#  'Bradwell Wind Farm (Repower)',
#  'Hazlehead',
#  'Kiln Pit Hill Windfarm',
#  'Otterham Down Wind Farm (Resubmission)',
#  'Sixpenny Wood Windfarm',
#  "Earl's Hall",
#  'Mawdesley Moss',
#  'Chelveston Renewable Energy Park Wind Farm (East Northamptonshire)',
#  'Bewick Drift',
#  'Hall Farm Routh',
#  'Rothes Wind Farm (Extension) (II)',
#  'Fforch Nest Wind Farm pt1',
#  'Hampole Wind Farm',
#  'Blackstone Edge',
#  'Marr Windfarm',
#  'Nissan Motors Plant Extn',
#  'Hill of Fiddes',
#  'Cotton Farm',
#  'Land at Flimby Hall Farm (resubmission)',
#  'Carland Cross Wind Farm Repowering',
#  'Yelvertoft Wind Farm',
#  'Mains of Hatton',
#  'Whitelee Windfarm Extension Phase 1',
#  'Tilbury Docks',
#  'Seamer Windfarm - Stockton on Tees',
#  'South Sharpley Wind Farm (Revised)',
#  'Armistead Wind Farm',
#  'Withernwick',
#  'Loch Sminig Wind Project',
#  'Burton Pidsea (Wadworth Hill) Wind Farm',
#  'Camster',
#  'Bu Farm',
#  'Drumderg',
#  'Clyde Wind Farm',
#  'Novar Wind Farm (Extension)',
#  'Hill of Towie (Drummuir)',
#  'Ewe Hill',
#  'Middlemoor',
#  'Baillie Wind Farm',
#  'Braich Ddu',
#  'Drone Hill',
#  'Tangy Wind Farm Extension/Tangy 2',
#  'Ray Wind Farm',
#  'Calliachar',
#  'Griffin Wind farm',
#  'High Pow Farm (Resubmission)',
#  'St. Johns Hill',
#  'Blackcraig',
#  'Fullabrook Down Wind Farm',
#  'Little Raith Farm',
#  'Pant y wal',
#  'Green Rigg',
#  'Rosehall Hill Forest Windfarm',
#  'Bankend Rig',
#  'Hill of Easterton Extension',
#  'Batsworthy Cross',
#  'Fallago Rig',
#  'Cathkin Braes Wind Farm (Castlemilk)',
#  'Mynydd y Betws',
#  'Ark Hill',
#  'Pentland Road Wind Farm',
#  'Turncole Wind Farm',
#  'Derby Sewage Treatment Works',
#  'Grange Resubmission',
#  'Goole Fields ll Wind Farm',
#  'Edintore Wind Farm',
#  'Gremista Wind Farm',
#  'Common Barn Wind Farm',
#  'Clentrie Wind Farm (Gevens)',
#  'Kelmarsh Wind Farm (Resubmission)',
#  'Torrance Farm Wind Park Extension',
#  'Goathill Quarry Turbine',
#  'Skeddoway Farm Wind Turbine (Resubmission)',
#  'Middle Balbeggie Wind Turbines',
#  'Upper Holton Wind Farm',
#  'Tallentire Hill',
#  'Meikle Carewe (Re-Submission)',
#  'Andershaw',
#  'East Midlands Airport',
#  'Kildrummy Windfarm',
#  'Airfield Farm (Podington) (Resubmission)',
#  'Dunmaglass Wind Farm',
#  'Harestanes',
#  'Corriemoillie (Resubmission)',
#  'Hill of Stroupster Windfarm',
#  'Burn of Whilk',
#  'Lochluichart',
#  'Burnhead',
#  'Easter Tolmauds',
#  'Maerdy',
#  'Woodlands Barton Wind Project',
#  'Westnewton',
#  'Hare Hill Extension',
#  'Avonmouth Port - extension',
#  'Barmoor South Wind Farm (Resubmission)',
#  'Winwick',
#  'Sisters',
#  'East Youlstone Wind Farm',
#  'Hill of Skilmafilly Cloffrickford (Denmore) Wind Farm',
#  'Heysham South Wind Farm',
#  'Woolley Hill Wind Farm',
#  'Furness Wind Farm/High Winds (Harlock Repowering)',
#  'Clyde Wind Farm Extension (Clyde 2)',
#  'Quixwood Moor',
#  'Auchadaduie Wind Farm',
#  'Mynydd Brombil Wind Farm',
#  'Mynydd Portref Wind Farm extension',
#  'Longlands Lane',
#  'Ryder Point Quarry Wind Turbines',
#  'Burton Wold Wind Farm - Northern Extension (resubmission)',
#  'Pearie Law Wind Farm',
#  'Crystal Rig Wind Farm Phase III',
#  'Drumduff',
#  'Rhodders Wind Farm',
#  'Harburnhead Wind Farm',
#  'Dunsland Cross Wind Farm',
#  'Potato Pot Wind Farm',
#  'Millour Hill Community Windfarm (Extension) resubmission',
#  'Blantyre Muir Wind Farm extension',
#  'Dorenell Wind Farm (Previously Site A and B Scaut Hill)',
#  'Earlsburn North (Kingsburn) Wind Farm',
#  'Wryde Croft',
#  'Wandylaw',
#  'Black Law Extension - 1a',
#  'Bishopthorpe',
#  'Keadby Wind Farm',
#  'Berry Burn',
#  'Afton Wind Farm',
#  'Tormywheel',
#  'Den Brook',
#  'Dersalloch',
#  'Point Wind / Beinn Ghrideag Farm',
#  'Muirhall South',
#  'Double Arches Quarry Wind Turbine',
#  'Lochend Wind Farm',
#  'KELLAS WIND FARM',
#  'Hallburn Farm (resubmission)',
#  'Coal Clough Wind Farm Repowering',
#  'Shepham Lane (Resubmission)',
#  'Sober Hill Wind Farm (Resubmission)',
#  'Srondoire Community Wind Farm',
#  'Achlachan Wind Farm',
#  "A'Chruach (Phase 1)",
#  'Aikengall II, Wester Dod Community Wind Farm',
#  'Alveston Wind Park',
#  'Auchrobert Wind Farm',
#  'Boardinghouse Wind Farm',
#  'Bogenlea Farm',
#  'BROWNIELEYS - 3 WIND TURBINES',
#  'Cairnborrow - resubmission',
#  'Crook Hill (Revised Application - Calderdale MBC) 1 of 2',
#  'Deuchries',
#  'Dungavel Hill',
#  'Earlseat',
#  'Easter Tulloch Wind Farm (Tullo Extension)',
#  'Galawhistle',
#  'Gayton Le Marsh Wind Farm',
#  'GlaxoSmithKline Wind Project (Turbine 4)',
#  'Goole Fields',
#  'Greenvale AP Wind Turbine - resubmission',
#  'Hill of Glaschyle Wind Farm',
#  'Kilgallioch wind farm',
#  'Lambs Hill',
#  'Lochluichart (Extension)',
#  'M1 Wind Farm',
#  'New Rides Wind Farm',
#  'Noble Foods',
#  'Ovenden Moor (Repower) (Re-submission)',
#  'Pant y wal extension',
#  'Park Spring Wind Farm',
#  'Brotherton (formerly Paul Matthew Hill wind turbines)',
#  'Pen Bryn Oer Wind Farm',
#  'Ramsey Wind Farm Extension',
#  'Red Gap Moor Wind Farm',
#  'Todmorden Moor  - Resubmission',
#  'Tom Nan Clach (redesign)',
#  'Tullo Wind Farm South (Ext.)',
#  'Watford Lodge',
#  'Wathegar 2 Wind Farm',
#  'West Browncastle',
#  'Brochloch Rig (formerly Windy Standard II)',
#  'Withernwick extension',
#  'Pogbie Wind Farm 1',
#  'Barlockhart Moor',
#  'Minnygap (Resubmission)',
#  'Middle Muir Wind Farm',
#  'Sanquhar Community Windfarm',
#  'Balmurrie Fell Wind Farm',
#  'Burnfoot Hill Extension',
#  'Airies Farm',
#  'Craig Wind Farm (Extension)',
#  'Lawrence Landfill',
#  'Plascow wind cluster (resubmission)',
#  'Maesgwyn Wind Farm - extension',
#  'Halifax Farm',
#  'Norton Fields Farm',
#  'Carscreugh Renewable Energy Park',
#  'Whiteside Hill',
#  'North Rhins',
#  'Jacksbank Wind Farm (Glenbervie)',
#  'New Albion Wind Farm',
#  'Sunnyside wind cluster',
#  'Keith Hill (resubmission)',
#  'Minsca',
#  'Artfield Fell',
#  'Wether Hill',
#  'Dalswinton',
#  'Craig Wind Farm',
#  'Beinn an Tuirc Phase 2',
#  'Aikengall',
#  'Brochloch Rig 1 (formerly Windy Standard)',
#  'Hawton Wind Farm',
#  'Beck Burn (resubmission)',
#  'Melton Common Wind Cluster',
#  'Hoprigshiels Community Wind Farm',
#  'Black Law Extension - 1b',
#  'Glen App',
#  'Pen Y Cymoedd',
#  'Stronelairg Wind Farm',
#  'M1 J18 Wind Turbines',
#  'Tullymurdoch Wind Farm',
#  'Penmanshiel Wind Farm',
#  'Kinegar Quarry (resubmission)',
#  'St. Breock Re-Power (Resubmission)',
#  'Carraig Gheal',
#  'Langhope Rig',
#  'Clashindarroch 2 (Revised)',
#  'Galsworthy Wind Park',
#  'Strathy North',
#  'Mid Hill - Phase II',
#  'Monan Hill Wind Turbines',
#  'French Farm (resubmission)',
#  'Glenchamber Wind Farm',
#  'Bhlaraidh (previously Balmacaan)',
#  'Moor House Wind Farm (resubmission)',
#  'Kype Muir Wind Farm',
#  'Llynfi Afan Renewable Energy Park',
#  'Assel Valley Wind Farm',
#  'Bad a Cheo Wind Farm',
#  'Fraisthorpe Wind Farm',
#  'Mynydd Y Gwair Wind Farm (resubmission)',
#  "Jack's Lane Wind Farm",
#  'Denzell Downs Wind Farm - resubmission',
#  'Reaps Moss Wind Farm (resubmitted)',
#  'Llynfi Renewable Energy Park, Land at Mynydd Caerau',
#  'Chiplow',
#  'Hook Moor',
#  'Crook Hill (Revised Application - Rochdale MBC) 2 of 2',
#  'Far Marsh Farm (Resubmission)',
#  'Wear Point',
#  'Middlewick wind farm',
#  'Blyth Harbour Wind Farm (re-power)',
#  'Corriegarth',
#  'Carsington Pasture',
#  'Langford Wind Farm',
#  'Mid Hill I',
#  'Ardrossan Extension',
#  'Beinn Tharsuinn Windfarm Project',
#  'Blaengwen (Re-Submission)',
#  'Boyndie Airfield',
#  'Burton Wold Windfarm',
#  'Edinbane Wind Farm',
#  'Fairburn',
#  'Farr Wind Farm',
#  'Ffynnon Oer Wind Farm',
#  'Flotta',
#  'Forss Wind Farm (Extension)',
#  'Michelin Tyre Co Ltd - Dundee',
#  'Millennium Windfarm',
#  'Muirhall',
#  'Mynydd Clogau Wind Farm',
#  'New Barn Farm',
#  'North Pickenham',
#  "Paul's Hill and Extension",
#  'Tir Mostyn And Foel Goch Wind Farm',
#  'Trimdon Grange',
#  'Wardlaw Wood',
#  'Southrigg',
#  'Kingspan',
#  'Gawnsmoss Cluster',
#  'Quarrendon Fields',
#  'Newstead and Annesley Wind Turbine',
#  'Beckton Sewage Treatment Works',
#  'Melton Waste Park (resubmission)',
#  'Burton Wold Wind Farm South',
#  'ANP Newport Wind Turbine',
#  'Brenig Wind Farm (Resubmission)',
#  'Pogbie Wind Farm 2',
#  'Bodtegir',
#  'West of Rhiwfelin Fach Farm',
#  'Marshill Farm',
#  'Woodlands Wind Farm',
#  'Accolade Wines',
#  'Craigannet Farm Wind Turbine',
#  'Ferneylea Farm',
#  'Forss Wind Farm',
#  'Land near Ventonteague (Resubmission)',
#  'Fen Farm Solar Park',
#  'Manor Farm',
#  'Nanterrow Farm',
#  'Howton Farm',
#  'East Langford Farm',
#  'Trevemper solar farm',
#  'Chester Energy (East Woolley Farm)',
#  'Chynoweth Farm',
#  'Carlton Farm Solar farm',
#  'Wheal Jane',
#  'Cantelupe Solar Farm',
#  'Benbole Farm',
#  'Langage Solar Farm',
#  'Grange Solar Farm',
#  'Ebbsfleet Farm Solar Farm',
#  'Westcott Venture Park Phase 2 & 3',
#  'Summerway Drove',
#  'Puriton Solar Farm',
#  'Toyota Solar Farm',
#  'Long Sutton Butterfly And Wildlife Park',
#  'Long Sutton Butterfly And Wildlife Park (extension)',
#  'Springhill Solar Park (Northwick)',
#  'Westmill Farm - PV',
#  'Rhosygilwen Solar Farm',
#  'Llancayo Solar Farm',
#  'Shacks Barn Solar Farm',
#  'Carines Farm Solar Array',
#  'Trigon Solar Farm',
#  'Chittering Solar Farm Extension',
#  'Tredinnick Fields',
#  'Summercourt Solar Farm (Glebe Farm)',
#  'Higher Trevartha Farm',
#  'Beechgrove Farm',
#  'PARK WOOD SOLAR FARM',
#  'Promens Solar',
#  'Malmesbury Solar',
#  'Trefullock Solar Farm',
#  'Lower Coombe Farm Solar',
#  'Durrants Farm Solar',
#  'Dunsfold Park Solar Farm',
#  'Alan Bartlett & Sons Solar',
#  'Tavells Lane Solar Farm',
#  'LITTLE TREVEASE SOLAR PARK',
#  'Cobbs Cross Solar Park',
#  'NOTTINGTON LANE SOLAR FARM',
#  'RUDGE FARM SOLAR FARM',
#  'CRINACOTT SOLAR FARM (Pyworthy)',
#  'Chawton Farm Solar Farm',
#  'VENTNOR ROAD SOLAR PARK',
#  'ROOKERY FARM SOLAR FARM',
#  'Little White Alice Solar Park',
#  'Park Wall Solar Park',
#  'Hall Farm Solar park',
#  'Oulton Airfield Solar Farm (Phase 1)',
#  'Chalcroft Solar Park',
#  'Bradford Solar Park',
#  'Lower Coombe Farm (Bean Field)',
#  'Ffos Las Racecourse',
#  'Woodforde Farm',
#  'Kingston Farm',
#  'Spriggs Farm',
#  'Rotherdale Farm',
#  'Turves Solar Farm (Resubmission)',
#  'Rexton Cross',
#  'Hatchlands Farm',
#  'Land At Potash Farm',
#  'Land at Upper Clayhill Farm',
#  'Towerbrook Farm (Banwell Solar Farm)',
#  'Twin Elm Solar Farm',
#  'Hardingham Solar Farm',
#  'Hollamoor Farm (PV)',
#  'Langlands Solar Farm',
#  'Langunnett Solar Farm',
#  'Manston Solar Farm',
#  'Marsh House Solar Park',
#  'Morrisons roof mounted solar',
#  'Rickfield Farm solar park',
#  'Tump Solar Farm',
#  'West Farm (Solar)',
#  'Owls Lodge Farm',
#  'Beckley Solar Farm',
#  'Oakham Farm',
#  'Limberlost Farm',
#  'Office Field',
#  'Sandys Moor Road',
#  'Skylark Meadow Solar park',
#  'Aldi Distribution Centre - Darlington',
#  'Bishops Sutton',
#  'Blackawton Solar Farm',
#  'BMW UK Manufacturing Ltd',
#  'Land to the East of Burton Lane',
#  'Land west of Hawkspur Green (Hill Hall Solar)',
#  'Kingspan Insulation Solar Installation',
#  'Langley Hall Farm',
#  'Pond Farm',
#  'Nether Mill Farm (resubmission)',
#  'NEWNTON DAIRY FARM',
#  'Pierces Farm - resubmission',
#  'Rew Farm Solar Farm',
#  'Westbury (Closed) Landfill Site',
#  'Wiggin Hill Solar Farm - Phase 2',
#  'Grain Harvesters Ltd',
#  'Hyde Farm',
#  'St Francis Farm',
#  'Bishops Waltham Solar Farm',
#  'Nova Scotia Farm solar park',
#  'Hall Farm, East Beckham',
#  'Cefn Betingau Farm',
#  'Hill Farm Solar Park (VoWH)',
#  'Wix Lodge',
#  'Saxley Farm',
#  'Snarlton Farm (Melksham solar farm)',
#  'Lackford Estate Solar Park',
#  'Colpmans Farm',
#  'Porvair International Ltd',
#  'Willsland Solar farm',
#  'Frying Down Copse Solar Farm',
#  'Wilmingham Lane Solar Farm',
#  'Chilton Cantelo Solar Farm',
#  'Beaford Brook Solar Park',
#  'Hayford Farm',
#  'Halse Farm',
#  'STRETE FARM SOLAR FARM',
#  'Tregassow Farm - Solar Modules',
#  'Higher Hatherleigh Solar Farm extension',
#  'Pont Andrew Solar Farm',
#  'Cairnhill Farm solar park',
#  'Manston Solar Farm extension (Westwood)',
#  'Newlands Farm Solar - resubmission',
#  'Fen Road',
#  'Long Meadow Farm',
#  'Liverton Farm',
#  'Home Farm (Knowlton - solar)',
#  'Lake Farm',
#  'Parkhouse Corner (Orta Solar)',
#  'Sandhill Solar Park',
#  'Mingay Farm',
#  'Jordanston Solar Farm',
#  'Aldi Distribution Centre - Neston',
#  'Rodbourne Rail Farm - Solar Park',
#  'Barnby Moor',
#  'Knockworthy Farm',
#  'Raglington Farm, Botley Road, Shedfield, Southampton, Hampshire',
#  'Stables Farm',
#  'Luson Farm',
#  'Kellygreen Farm',
#  'Grove Farm (solar)',
#  'Marston Solar Farm',
#  'Tredown Solar Farm',
#  'Slaughtergate Farm',
#  'Kia Ora Farm',
#  'Ellicombe Farm',
#  'Southcombe Farm',
#  'West Bradley Farm',
#  'Whiddon Farm',
#  'Lovedean Farm',
#  'Higher Knapp Farm',
#  'Park Farm',
#  'Dunkeswell Airfield',
#  'Langenhoe Solar Farm',
#  'Kentishes Solar Farm',
#  'Marley Thatch Solar Farm',
#  'Newlands Farm (East Devon)',
#  'Goldthorpe',
#  'Barley Wood Farm Lane (Gaston Lane - resubmission)',
#  'Battens Farm Solar Park',
#  'Combermere Abbey',
#  'Foxburrow Farm',
#  'Great Houndbeare Farm',
#  'Condover (Green Farm)',
#  'Hurst Farm',
#  'Ikea Distribution Centre - resubmission',
#  'Jaguar Land Rover',
#  'Leverton Ings',
#  'Little Morton Solar Farm',
#  'Lodge Farm - Orston',
#  'Lowther Farms',
#  'Mackies Dairy PV',
#  'Mingay Farm - extension',
#  'Redcourt Farm',
#  'Sowerby Lodge Farm',
#  'Stone Hill',
#  'Taunton Racecourse',
#  'The Stables',
#  'Vantage Point',
#  'Wilsom Farm',
#  'Woodlands Farm Solar Park',
#  'Bowerhouse Farm',
#  'Brickyard Barn (resubmission)',
#  'Bronwylfa Reservoir',
#  'Land At Court Farm',
#  'Crapnell Farm Solar Farm',
#  'Danes Farm - extension',
#  'Ellough Airfield (Resubmission)',
#  'Ermine Street Farm solar park',
#  'Eynsham Solar Farm',
#  'Ford Farm (Ashurst)',
#  'Priors Byne Farm',
#  'Scottow Moor - RAF Coltishall Solar Farm (Phase 1)',
#  'Owls Lodge Farm Extension',
#  'Hawksland Solar',
#  'Middle Treworder Farm',
#  'Black Bush Farm',
#  'Goonhilly Downs - PV',
#  'Higher Tregarne Solar Farm',
#  'Causilgey Solar Farm',
#  'Ninnis Farm Solar',
#  'Trelow Farm',
#  'Hewas Solar Farm',
#  'Great Knowle Farm Solar',
#  'Airfield Farm PV',
#  'Lower Bodiniel Farm',
#  'Shelswell Park Solar Farm',
#  'Chittering Solar Farm',
#  'Kernow Solar Farm',
#  'Limes Farm Solar Farm',
#  'Bratton Fleming Solar Farm',
#  'Lee Farm',
#  'Woodlands Barton Solar Farm',
#  'Winsdon Farm',
#  'The Manor of Cadland Estate',
#  'Trenouth Farm',
#  'Callington Solar Farm',
#  'St Columb Major Solar Farm',
#  'Crossways Pit Solar Farm',
#  'Ayshford Court Farm',
#  'Andover Solar Farm',
#  'Oving Solar Farm',
#  'Grange Farm (Cornwall)',
#  'Shipton Bellinger - Park House Corner Solar Farm',
#  'Wyld Meadow Solar Farm',
#  'Shooters Bottom Solar Park',
#  'Goldenhaye Field Solar Farm',
#  'Clearwell Farm - solar',
#  'Danes Farm',
#  'Langstone Court Road Solar Farm',
#  'Five Oaks Solar Farm',
#  'Culworth House Solar Farm',
#  'Warleigh Barton Solar Farm',
#  'Trenoweth Solar Farm',
#  'Wymeswold Airfield',
#  'Higher Hatherleigh Solar Farm',
#  'Barton Solar Farm',
#  'Clann Solar Farm',
#  'Dolmans Hill (Redbridge Farm) Solar Arrays',
#  'North Norfolk Business Centre Solar Park',
#  'Horsacott Farm Solar Park',
#  'Broxted Solar Farm (Stradishall Airfield)',
#  'Pentylands Farm',
#  'Trefinnick Farm',
#  'Four Burrows Solar farm',
#  'Rudbaxton Solar Park',
#  'Hope Solar Farm',
#  'Culmhead Solar Farm (Resubmission)',
#  'Wheal Alfred Road Solar Farm',
#  'Blatchworthy Farm',
#  'Parsonage Barn (extension)',
#  'BIOSSENCE SOLAR PARK',
#  'HENDRA HOLIDAY PARK SOLAR FARM',
#  'EASTACOMBE SOLAR FARM',
#  'Wrexham Social Housing PV',
#  'Creathorne Farm  - Solar Farm',
#  'Higher Pirzwell Solar Farm',
#  'Broadgate Solar Farm',
#  'CRAYSMARSH SOLAR FARM',
#  'SOLAR PARK - WHITCHURCH FARM',
#  ...]

# %%
whitelee = df_RES.loc[:, 'Whitelee']
whitelee = df_RES[['Whitelee']]
whitelee
# Out:
#                      Whitelee
# name
# 2050-01-01 00:00:00  0.915911
# 2050-01-01 00:30:00  0.767069
# 2050-01-01 01:00:00  0.632692
# 2050-01-01 01:30:00  0.512778
# 2050-01-01 02:00:00  0.407853
# ...                       ...
# 2050-12-31 21:30:00  0.114266
# 2050-12-31 22:00:00  0.124903
# 2050-12-31 22:30:00  0.135496
# 2050-12-31 23:00:00  0.146044
# 2050-12-31 23:30:00  0.146044
#
# [17520 rows x 1 columns]

# %%
whitelee.plot(linestyle='-', figsize=(15,10))
plt.title('Whitelee output over year', fontsize=20)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Power normalised', fontsize=18)
# Out:
# Text(0, 0.5, 'Power normalised')

# %%
whitelee['2050-01-01 00:00:00': '2050-01-01 23:30:00'].plot(linestyle='-', figsize=(15,10))
plt.title('Whitelee over 01/01/' + str(year), fontsize=20)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Power normalised', fontsize=18)
# Out:
# Text(0, 0.5, 'Power normalised')

# %%
s = whitelee.index
s_index = pd.to_datetime(s, infer_datetime_format=True)
whitelee.index = s_index
whitelee.loc[:, 'Month'] = whitelee.index.month
# Box plots over whole dataset for month values
fig, ax = plt.subplots()
fig.set_size_inches(15,10)
sns.boxplot(data=whitelee, x='Month', y='Whitelee')
ax.set_title('Boxplot for Whitelee power normalised power output', fontsize=20)
ax.set_xlabel('Month', fontsize=18)
ax.set_ylabel('Supply [kWh]', fontsize=18)
# Out:
# C:\Users\alyden\AppData\Local\Temp\ipykernel_6648\3196715207.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   s_index = pd.to_datetime(s, infer_datetime_format=True)
# Text(0, 0.5, 'Supply [kWh]')

# %% [markdown]
# ## Historical storage units

# %%
import storage
year = 2015
storage.read_storage_data(year)
# Out:
#          name  bus  p_nom                       carrier  marginal_cost  \
# 0    Dinorwig  bus   1728  Pumped Storage Hydroelectric              0
# 1  Ffestiniog  bus    360  Pumped Storage Hydroelectric              0
# 2    Cruachan  bus    440  Pumped Storage Hydroelectric              0
# 3      Foyers  bus    300  Pumped Storage Hydroelectric              0
#
#    max_hours  efficiency_store  efficiency_dispatch         x          y
# 0      5.266             0.865                0.865 -4.113899  53.118623
# 1      3.889             0.850                0.850 -3.968897  52.980848
# 2     16.136             0.865                0.865 -5.113430  56.411140
# 3     21.000             0.865                0.865 -4.493816  57.254341

# %%
df_storage = storage.write_storage_units(year, scenario='Leading the Way', FES=2022)
storage_p_nom = df_storage.p_nom.groupby(df_storage.carrier).sum()
storage_p_nom
# Out:
# carrier
# Pumped Storage Hydroelectric    2828
# Name: p_nom, dtype: int64
